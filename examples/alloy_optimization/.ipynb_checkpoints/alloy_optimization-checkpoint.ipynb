# %% [markdown]
# ## Alloy optimization
#
# Using a toy model, multi-objective optimization is employed to select the cheapest alloys exhibiting enhanced *X* property after mixing.

# %%
import mosa
from numpy import random, arange, asarray

# %matplotlib inline

# %%
random.seed(0)

# %% [markdown]
# The pure, fictitious elements have symbols in the **A**...**Z** range. The *X* property and the cost associated with the pure elements was generated by the *generate_data* function below.

# %%
def generate_data(component):
    k = arange(component.shape[0]) + 1

    x0 = 0.5
    x1 = 12.6
    x = x0 * k + x1 + random.uniform(0.0, 5.0, component.shape[0])

    cost = random.uniform(5.0, 500.0, component.shape[0])

    return x, cost

# %% [markdown]
# ### Translating the alloy optimization problem into Python code
#
# The function *fobj* below implements the problem. The two objectives to be minimized are the *X* property and the final cost of the proposed alloy.
#
# The solution to the problem consists of two groups. "Component" is a list, where the first element is the matrix element and the second is the alloying element. "Concentration" gives the relative amount of the alloying element in the alloy.
#
# Notice that both *X* and cost of the alloy results from a simple mixing rule considering *X* and cost of the pure elements.
#
# Also, maximizing *X* is equivalent to minimizing -*X*, that is why -*x* is returned by *fobj*.

# %%
def fobj(Component: list, Concentration: float) -> tuple:
    first, second = Component

    x1 = float(X[component == first][0])
    cost1 = float(Cost[component == first][0])

    x2 = float(X[component == second][0])
    cost2 = float(Cost[component == second][0])

    x = x1 * (1.0 - Concentration) + x2 * Concentration
    cost = cost1 * (1.0 - Concentration) + cost2 * Concentration

    return -x, cost

# %%
component = asarray(list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))

# %%
X, Cost = generate_data(component)

# %% [markdown]
# ### Initialization

# %%
opt = mosa.Anneal()
# Out:
# --------------------------------------------------
#  MULTI-OBJECTIVE SIMULATED ANNEALING (MOSA) 1.0.0
# --------------------------------------------------

# %%
opt.set_population(Component=component.tolist(), Concentration=(0.0, 0.1))

# %%
opt.initial_temperature = 1.0
opt.number_of_temperatures = 100
opt.number_of_iterations = 200
opt.objective_weights = [(X.max() - X.min()), (Cost.max() - Cost.min())]
opt.archive_size = 1000
opt.maximum_archive_rejections = 1000
opt.adaptative_selection = True

# %%
opt.set_opt_param("number_of_elements", Component=2, Concentration=1)
opt.set_opt_param("group_selection_weights", Component=1.0, Concentration=4.0)
opt.set_opt_param("distinct_elements", Component=True)
opt.set_opt_param("change_value_move", Component=1.0, Concentration=1.0)
opt.set_opt_param("swap_move", Component=1.0)
opt.set_opt_param("mc_step_size", Concentration=0.05)

# %%
opt.verbose = True

# %% [markdown]
# IMPORTANT: Restarting from previous runs is disabled.

# %%
opt.restart = False

# %% [markdown]
# ### Run 1

# %%
# %%time
random.seed(1)
opt.archive_file = "archive1.json"
opt.evolve(fobj)
archive1 = opt.copyx()
# Out:
# --- BEGIN: Evolving a solution ---
#
# Initializing an empty archive...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     Component:
#         Number of elements: 2
#         Sample space: discrete
#         Size of population group: 26
#         Distinct elements: True
#         Selection probability: 0.200000
#         Weight of 'change value' trial move: 1.0
#         Weight of 'swap' trial move: 1.0
#         Sort values: False
#         Maximum step size: 13
#     Concentration:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,0.1)
#         Selection probability: 0.800000
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.05
# ------
# Initializing with a random solution from scratch...
# Done!
# ------
# TEMPERATURE: 1.000000
#     Number of accepted moves: 189.
#     Fraction of accepted moves: 0.945000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.121693.
# ------
# TEMPERATURE: 0.900000
#     Group selection probabilities:
#         Component: 0.604013
#         Concentration: 0.395987
#     Number of accepted moves: 162.
#     Fraction of accepted moves: 0.810000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.123457.
# ------
# TEMPERATURE: 0.810000
#     Group selection probabilities:
#         Component: 0.540965
#         Concentration: 0.459035
#     Number of accepted moves: 167.
#     Fraction of accepted moves: 0.835000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.047904.
# ------
# TEMPERATURE: 0.729000
#     Group selection probabilities:
#         Component: 0.591718
#         Concentration: 0.408282
#     Number of accepted moves: 166.
#     Fraction of accepted moves: 0.830000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.054217.
# ------
# TEMPERATURE: 0.656100
#     Group selection probabilities:
#         Component: 0.577757
#         Concentration: 0.422243
#     Number of accepted moves: 173.
#     Fraction of accepted moves: 0.865000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.104046.
# ------
# TEMPERATURE: 0.590490
#     Group selection probabilities:
#         Component: 0.586393
#         Concentration: 0.413607
#     Number of accepted moves: 170.
#     Fraction of accepted moves: 0.850000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.058824.
# ------
# TEMPERATURE: 0.531441
#     Group selection probabilities:
#         Component: 0.608360
#         Concentration: 0.391640
#     Number of accepted moves: 132.
#     Fraction of accepted moves: 0.660000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.113636.
# ------
# TEMPERATURE: 0.478297
#     Group selection probabilities:
#         Component: 0.539001
#         Concentration: 0.460999
#     Number of accepted moves: 153.
#     Fraction of accepted moves: 0.765000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.137255.
# ------
# TEMPERATURE: 0.430467
#     Group selection probabilities:
#         Component: 0.603003
#         Concentration: 0.396997
#     Number of accepted moves: 161.
#     Fraction of accepted moves: 0.805000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.049689.
# ------
# TEMPERATURE: 0.387420
#     Group selection probabilities:
#         Component: 0.596930
#         Concentration: 0.403070
#     Number of accepted moves: 140.
#     Fraction of accepted moves: 0.700000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.014286.
# ------
# TEMPERATURE: 0.348678
#     Group selection probabilities:
#         Component: 0.512259
#         Concentration: 0.487741
#     Number of accepted moves: 141.
#     Fraction of accepted moves: 0.705000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.120567.
# ------
# TEMPERATURE: 0.313811
#     Group selection probabilities:
#         Component: 0.545527
#         Concentration: 0.454473
#     Number of accepted moves: 133.
#     Fraction of accepted moves: 0.665000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.112782.
# ------
# TEMPERATURE: 0.282430
#     Group selection probabilities:
#         Component: 0.614042
#         Concentration: 0.385958
#     Number of accepted moves: 136.
#     Fraction of accepted moves: 0.680000.
#     Number of archive updates: 24.
#     Fraction of archive updates in accepted moves: 0.176471.
# ------
# TEMPERATURE: 0.254187
#     Group selection probabilities:
#         Component: 0.615931
#         Concentration: 0.384069
#     Number of accepted moves: 110.
#     Fraction of accepted moves: 0.550000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.018182.
# ------
# TEMPERATURE: 0.228768
#     Group selection probabilities:
#         Component: 0.539052
#         Concentration: 0.460948
#     Number of accepted moves: 142.
#     Fraction of accepted moves: 0.710000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.218310.
# ------
# TEMPERATURE: 0.205891
#     Group selection probabilities:
#         Component: 0.533737
#         Concentration: 0.466263
#     Number of accepted moves: 119.
#     Fraction of accepted moves: 0.595000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.058824.
# ------
# TEMPERATURE: 0.185302
#     Group selection probabilities:
#         Component: 0.642803
#         Concentration: 0.357197
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.475000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.189474.
# ------
# TEMPERATURE: 0.166772
#     Group selection probabilities:
#         Component: 0.592164
#         Concentration: 0.407836
#     Number of accepted moves: 106.
#     Fraction of accepted moves: 0.530000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.028302.
# ------
# TEMPERATURE: 0.150095
#     Group selection probabilities:
#         Component: 0.553683
#         Concentration: 0.446317
#     Number of accepted moves: 100.
#     Fraction of accepted moves: 0.500000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.110000.
# ------
# TEMPERATURE: 0.135085
#     Group selection probabilities:
#         Component: 0.507487
#         Concentration: 0.492513
#     Number of accepted moves: 119.
#     Fraction of accepted moves: 0.595000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.016807.
# ------
# TEMPERATURE: 0.121577
#     Group selection probabilities:
#         Component: 0.541576
#         Concentration: 0.458424
#     Number of accepted moves: 107.
#     Fraction of accepted moves: 0.535000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.177570.
# ------
# TEMPERATURE: 0.109419
#     Group selection probabilities:
#         Component: 0.517229
#         Concentration: 0.482771
#     Number of accepted moves: 112.
#     Fraction of accepted moves: 0.560000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.080357.
# ------
# TEMPERATURE: 0.098477
#     Group selection probabilities:
#         Component: 0.632047
#         Concentration: 0.367953
#     Number of accepted moves: 85.
#     Fraction of accepted moves: 0.425000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.258824.
# ------
# TEMPERATURE: 0.088629
#     Group selection probabilities:
#         Component: 0.559013
#         Concentration: 0.440987
#     Number of accepted moves: 110.
#     Fraction of accepted moves: 0.550000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.090909.
# ------
# TEMPERATURE: 0.079766
#     Group selection probabilities:
#         Component: 0.477954
#         Concentration: 0.522046
#     Number of accepted moves: 115.
#     Fraction of accepted moves: 0.575000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.156522.
# ------
# TEMPERATURE: 0.071790
#     Group selection probabilities:
#         Component: 0.518136
#         Concentration: 0.481864
#     Number of accepted moves: 102.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.098039.
# ------
# TEMPERATURE: 0.064611
#     Group selection probabilities:
#         Component: 0.603273
#         Concentration: 0.396727
#     Number of accepted moves: 86.
#     Fraction of accepted moves: 0.430000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.209302.
# ------
# TEMPERATURE: 0.058150
#     Group selection probabilities:
#         Component: 0.542932
#         Concentration: 0.457068
#     Number of accepted moves: 115.
#     Fraction of accepted moves: 0.575000.
#     Number of archive updates: 32.
#     Fraction of archive updates in accepted moves: 0.278261.
# ------
# TEMPERATURE: 0.052335
#     Group selection probabilities:
#         Component: 0.572502
#         Concentration: 0.427498
#     Number of accepted moves: 105.
#     Fraction of accepted moves: 0.525000.
#     Number of archive updates: 26.
#     Fraction of archive updates in accepted moves: 0.247619.
# ------
# TEMPERATURE: 0.047101
#     Group selection probabilities:
#         Component: 0.681495
#         Concentration: 0.318505
#     Number of accepted moves: 93.
#     Fraction of accepted moves: 0.465000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.107527.
# ------
# TEMPERATURE: 0.042391
#     Group selection probabilities:
#         Component: 0.509663
#         Concentration: 0.490337
#     Number of accepted moves: 96.
#     Fraction of accepted moves: 0.480000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.208333.
# ------
# TEMPERATURE: 0.038152
#     Group selection probabilities:
#         Component: 0.524139
#         Concentration: 0.475861
#     Number of accepted moves: 89.
#     Fraction of accepted moves: 0.445000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.078652.
# ------
# TEMPERATURE: 0.034337
#     Group selection probabilities:
#         Component: 0.546226
#         Concentration: 0.453774
#     Number of accepted moves: 76.
#     Fraction of accepted moves: 0.380000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.157895.
# ------
# TEMPERATURE: 0.030903
#     Group selection probabilities:
#         Component: 0.532633
#         Concentration: 0.467367
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.405000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.382716.
# ------
# TEMPERATURE: 0.027813
#     Group selection probabilities:
#         Component: 0.528924
#         Concentration: 0.471076
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.405000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.024691.
# ------
# TEMPERATURE: 0.025032
#     Group selection probabilities:
#         Component: 0.470542
#         Concentration: 0.529458
#     Number of accepted moves: 107.
#     Fraction of accepted moves: 0.535000.
#     Number of archive updates: 61.
#     Fraction of archive updates in accepted moves: 0.570093.
# ------
# TEMPERATURE: 0.022528
#     Group selection probabilities:
#         Component: 0.517882
#         Concentration: 0.482118
#     Number of accepted moves: 70.
#     Fraction of accepted moves: 0.350000.
#     Number of archive updates: 39.
#     Fraction of archive updates in accepted moves: 0.557143.
# ------
# TEMPERATURE: 0.020276
#     Group selection probabilities:
#         Component: 0.503839
#         Concentration: 0.496161
#     Number of accepted moves: 64.
#     Fraction of accepted moves: 0.320000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.343750.
# ------
# TEMPERATURE: 0.018248
#     Group selection probabilities:
#         Component: 0.430967
#         Concentration: 0.569033
#     Number of accepted moves: 83.
#     Fraction of accepted moves: 0.415000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.373494.
# ------
# TEMPERATURE: 0.016423
#     Group selection probabilities:
#         Component: 0.553183
#         Concentration: 0.446817
#     Number of accepted moves: 77.
#     Fraction of accepted moves: 0.385000.
#     Number of archive updates: 67.
#     Fraction of archive updates in accepted moves: 0.870130.
# ------
# TEMPERATURE: 0.014781
#     Group selection probabilities:
#         Component: 0.521668
#         Concentration: 0.478332
#     Number of accepted moves: 61.
#     Fraction of accepted moves: 0.305000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.311475.
# ------
# TEMPERATURE: 0.013303
#     Group selection probabilities:
#         Component: 0.438266
#         Concentration: 0.561734
#     Number of accepted moves: 65.
#     Fraction of accepted moves: 0.325000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.123077.
# ------
# TEMPERATURE: 0.011973
#     Group selection probabilities:
#         Component: 0.527538
#         Concentration: 0.472462
#     Number of accepted moves: 45.
#     Fraction of accepted moves: 0.225000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.111111.
# ------
# TEMPERATURE: 0.010775
#     Group selection probabilities:
#         Component: 0.327464
#         Concentration: 0.672536
#     Number of accepted moves: 85.
#     Fraction of accepted moves: 0.425000.
#     Number of archive updates: 77.
#     Fraction of archive updates in accepted moves: 0.905882.
# ------
# TEMPERATURE: 0.009698
#     Group selection probabilities:
#         Component: 0.460392
#         Concentration: 0.539608
#     Number of accepted moves: 67.
#     Fraction of accepted moves: 0.335000.
#     Number of archive updates: 44.
#     Fraction of archive updates in accepted moves: 0.656716.
# ------
# TEMPERATURE: 0.008728
#     Group selection probabilities:
#         Component: 0.464852
#         Concentration: 0.535148
#     Number of accepted moves: 75.
#     Fraction of accepted moves: 0.375000.
#     Number of archive updates: 67.
#     Fraction of archive updates in accepted moves: 0.893333.
# ------
# TEMPERATURE: 0.007855
#     Group selection probabilities:
#         Component: 0.489174
#         Concentration: 0.510826
#     Number of accepted moves: 70.
#     Fraction of accepted moves: 0.350000.
#     Number of archive updates: 30.
#     Fraction of archive updates in accepted moves: 0.428571.
# ------
# TEMPERATURE: 0.007070
#     Group selection probabilities:
#         Component: 0.440685
#         Concentration: 0.559315
#     Number of accepted moves: 48.
#     Fraction of accepted moves: 0.240000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.354167.
# ------
# TEMPERATURE: 0.006363
#     Group selection probabilities:
#         Component: 0.371405
#         Concentration: 0.628595
#     Number of accepted moves: 67.
#     Fraction of accepted moves: 0.335000.
#     Number of archive updates: 48.
#     Fraction of archive updates in accepted moves: 0.716418.
# ------
# TEMPERATURE: 0.005726
#     Group selection probabilities:
#         Component: 0.444749
#         Concentration: 0.555251
#     Number of accepted moves: 50.
#     Fraction of accepted moves: 0.250000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.400000.
# ------
# TEMPERATURE: 0.005154
#     Group selection probabilities:
#         Component: 0.436541
#         Concentration: 0.563459
#     Number of accepted moves: 51.
#     Fraction of accepted moves: 0.255000.
#     Number of archive updates: 32.
#     Fraction of archive updates in accepted moves: 0.627451.
# ------
# TEMPERATURE: 0.004638
#     Group selection probabilities:
#         Component: 0.555205
#         Concentration: 0.444795
#     Number of accepted moves: 50.
#     Fraction of accepted moves: 0.250000.
#     Number of archive updates: 35.
#     Fraction of archive updates in accepted moves: 0.700000.
# ------
# TEMPERATURE: 0.004175
#     Group selection probabilities:
#         Component: 0.393007
#         Concentration: 0.606993
#     Number of accepted moves: 54.
#     Fraction of accepted moves: 0.270000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.037037.
# ------
# TEMPERATURE: 0.003757
#     Group selection probabilities:
#         Component: 0.570280
#         Concentration: 0.429720
#     Number of accepted moves: 47.
#     Fraction of accepted moves: 0.235000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.021277.
# ------
# TEMPERATURE: 0.003381
#     Group selection probabilities:
#         Component: 0.617585
#         Concentration: 0.382415
#     Number of accepted moves: 46.
#     Fraction of accepted moves: 0.230000.
#     No archive update.
# ------
# TEMPERATURE: 0.003043
#     Group selection probabilities:
#         Component: 0.654097
#         Concentration: 0.345903
#     Number of accepted moves: 26.
#     Fraction of accepted moves: 0.130000.
#     No archive update.
# ------
# TEMPERATURE: 0.002739
#     Group selection probabilities:
#         Component: 0.671814
#         Concentration: 0.328186
#     Number of accepted moves: 25.
#     Fraction of accepted moves: 0.125000.
#     No archive update.
# ------
# TEMPERATURE: 0.002465
#     Group selection probabilities:
#         Component: 0.401911
#         Concentration: 0.598089
#     Number of accepted moves: 23.
#     Fraction of accepted moves: 0.115000.
#     No archive update.
# ------
# TEMPERATURE: 0.002219
#     Group selection probabilities:
#         Component: 0.315396
#         Concentration: 0.684604
#     Insertion in the archive consecutively rejected 1000 times!
#     Stoping at iteration 75...
# ------
#
# --- THE END ---
# CPU times: total: 3.31 s
# Wall time: 4.47 s

# %% [markdown]
# ### Output 1

# %%
print(f"Number of solutions stored in the first archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the first archive: 1000

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.79699164357297, 14.477926517355263]
# Max: [-21.924174143044134, 221.78149739067837]
# Avg: [-27.540303223402926, 80.64281737483637]
# Std: [0.7153610953192802, 36.23919249600618]

# %%
opt.plot_front()

# %% [markdown]
# ### Run 2

# %%
# %%time
random.seed(2)
opt.archive_file = "archive2.json"
opt.evolve(fobj)
archive2 = opt.copyx()
# Out:
# --- BEGIN: Evolving a solution ---
#
# Initializing an empty archive...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     Component:
#         Number of elements: 2
#         Sample space: discrete
#         Size of population group: 26
#         Distinct elements: True
#         Selection probability: 0.315396
#         Weight of 'change value' trial move: 1.0
#         Weight of 'swap' trial move: 1.0
#         Sort values: False
#         Maximum step size: 13
#     Concentration:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,0.1)
#         Selection probability: 0.684604
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.05
# ------
# Initializing with a random solution from scratch...
# Done!
# ------
# TEMPERATURE: 1.000000
#     Number of accepted moves: 193.
#     Fraction of accepted moves: 0.965000.
#     Number of archive updates: 43.
#     Fraction of archive updates in accepted moves: 0.222798.
# ------
# TEMPERATURE: 0.900000
#     Group selection probabilities:
#         Component: 0.562954
#         Concentration: 0.437046
#     Number of accepted moves: 161.
#     Fraction of accepted moves: 0.805000.
#     Number of archive updates: 34.
#     Fraction of archive updates in accepted moves: 0.211180.
# ------
# TEMPERATURE: 0.810000
#     Group selection probabilities:
#         Component: 0.584186
#         Concentration: 0.415814
#     Number of accepted moves: 181.
#     Fraction of accepted moves: 0.905000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.066298.
# ------
# TEMPERATURE: 0.729000
#     Group selection probabilities:
#         Component: 0.537255
#         Concentration: 0.462745
#     Number of accepted moves: 164.
#     Fraction of accepted moves: 0.820000.
#     Number of archive updates: 35.
#     Fraction of archive updates in accepted moves: 0.213415.
# ------
# TEMPERATURE: 0.656100
#     Group selection probabilities:
#         Component: 0.593232
#         Concentration: 0.406768
#     Number of accepted moves: 153.
#     Fraction of accepted moves: 0.765000.
#     Number of archive updates: 27.
#     Fraction of archive updates in accepted moves: 0.176471.
# ------
# TEMPERATURE: 0.590490
#     Group selection probabilities:
#         Component: 0.565295
#         Concentration: 0.434705
#     Number of accepted moves: 160.
#     Fraction of accepted moves: 0.800000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.006250.
# ------
# TEMPERATURE: 0.531441
#     Group selection probabilities:
#         Component: 0.580353
#         Concentration: 0.419647
#     Number of accepted moves: 170.
#     Fraction of accepted moves: 0.850000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.041176.
# ------
# TEMPERATURE: 0.478297
#     Group selection probabilities:
#         Component: 0.543304
#         Concentration: 0.456696
#     Number of accepted moves: 162.
#     Fraction of accepted moves: 0.810000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.092593.
# ------
# TEMPERATURE: 0.430467
#     Group selection probabilities:
#         Component: 0.632553
#         Concentration: 0.367447
#     Number of accepted moves: 142.
#     Fraction of accepted moves: 0.710000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.105634.
# ------
# TEMPERATURE: 0.387420
#     Group selection probabilities:
#         Component: 0.611471
#         Concentration: 0.388529
#     Number of accepted moves: 127.
#     Fraction of accepted moves: 0.635000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.157480.
# ------
# TEMPERATURE: 0.348678
#     Group selection probabilities:
#         Component: 0.608398
#         Concentration: 0.391602
#     Number of accepted moves: 133.
#     Fraction of accepted moves: 0.665000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.007519.
# ------
# TEMPERATURE: 0.313811
#     Group selection probabilities:
#         Component: 0.620629
#         Concentration: 0.379371
#     Number of accepted moves: 116.
#     Fraction of accepted moves: 0.580000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.077586.
# ------
# TEMPERATURE: 0.282430
#     Group selection probabilities:
#         Component: 0.512882
#         Concentration: 0.487118
#     Number of accepted moves: 137.
#     Fraction of accepted moves: 0.685000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.065693.
# ------
# TEMPERATURE: 0.254187
#     Group selection probabilities:
#         Component: 0.563195
#         Concentration: 0.436805
#     Number of accepted moves: 140.
#     Fraction of accepted moves: 0.700000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.050000.
# ------
# TEMPERATURE: 0.228768
#     Group selection probabilities:
#         Component: 0.622400
#         Concentration: 0.377600
#     Number of accepted moves: 119.
#     Fraction of accepted moves: 0.595000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.176471.
# ------
# TEMPERATURE: 0.205891
#     Group selection probabilities:
#         Component: 0.533394
#         Concentration: 0.466606
#     Number of accepted moves: 125.
#     Fraction of accepted moves: 0.625000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.136000.
# ------
# TEMPERATURE: 0.185302
#     Group selection probabilities:
#         Component: 0.729526
#         Concentration: 0.270474
#     Number of accepted moves: 108.
#     Fraction of accepted moves: 0.540000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.203704.
# ------
# TEMPERATURE: 0.166772
#     Group selection probabilities:
#         Component: 0.568816
#         Concentration: 0.431184
#     Number of accepted moves: 124.
#     Fraction of accepted moves: 0.620000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.201613.
# ------
# TEMPERATURE: 0.150095
#     Group selection probabilities:
#         Component: 0.521512
#         Concentration: 0.478488
#     Number of accepted moves: 125.
#     Fraction of accepted moves: 0.625000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.168000.
# ------
# TEMPERATURE: 0.135085
#     Group selection probabilities:
#         Component: 0.554039
#         Concentration: 0.445961
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.475000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.010526.
# ------
# TEMPERATURE: 0.121577
#     Group selection probabilities:
#         Component: 0.524908
#         Concentration: 0.475092
#     Number of accepted moves: 111.
#     Fraction of accepted moves: 0.555000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.279279.
# ------
# TEMPERATURE: 0.109419
#     Group selection probabilities:
#         Component: 0.621983
#         Concentration: 0.378017
#     Number of accepted moves: 98.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 16.
#     Fraction of archive updates in accepted moves: 0.163265.
# ------
# TEMPERATURE: 0.098477
#     Group selection probabilities:
#         Component: 0.576601
#         Concentration: 0.423399
#     Number of accepted moves: 106.
#     Fraction of accepted moves: 0.530000.
#     Number of archive updates: 28.
#     Fraction of archive updates in accepted moves: 0.264151.
# ------
# TEMPERATURE: 0.088629
#     Group selection probabilities:
#         Component: 0.509929
#         Concentration: 0.490071
#     Number of accepted moves: 115.
#     Fraction of accepted moves: 0.575000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.269565.
# ------
# TEMPERATURE: 0.079766
#     Group selection probabilities:
#         Component: 0.557230
#         Concentration: 0.442770
#     Number of accepted moves: 91.
#     Fraction of accepted moves: 0.455000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.054945.
# ------
# TEMPERATURE: 0.071790
#     Group selection probabilities:
#         Component: 0.506587
#         Concentration: 0.493413
#     Number of accepted moves: 103.
#     Fraction of accepted moves: 0.515000.
#     Number of archive updates: 27.
#     Fraction of archive updates in accepted moves: 0.262136.
# ------
# TEMPERATURE: 0.064611
#     Group selection probabilities:
#         Component: 0.514246
#         Concentration: 0.485754
#     Number of accepted moves: 99.
#     Fraction of accepted moves: 0.495000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.080808.
# ------
# TEMPERATURE: 0.058150
#     Group selection probabilities:
#         Component: 0.493358
#         Concentration: 0.506642
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.475000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.042105.
# ------
# TEMPERATURE: 0.052335
#     Group selection probabilities:
#         Component: 0.465899
#         Concentration: 0.534101
#     Number of accepted moves: 106.
#     Fraction of accepted moves: 0.530000.
#     Number of archive updates: 43.
#     Fraction of archive updates in accepted moves: 0.405660.
# ------
# TEMPERATURE: 0.047101
#     Group selection probabilities:
#         Component: 0.570525
#         Concentration: 0.429475
#     Number of accepted moves: 82.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.219512.
# ------
# TEMPERATURE: 0.042391
#     Group selection probabilities:
#         Component: 0.470085
#         Concentration: 0.529915
#     Number of accepted moves: 87.
#     Fraction of accepted moves: 0.435000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.137931.
# ------
# TEMPERATURE: 0.038152
#     Group selection probabilities:
#         Component: 0.545444
#         Concentration: 0.454556
#     Number of accepted moves: 86.
#     Fraction of accepted moves: 0.430000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.290698.
# ------
# TEMPERATURE: 0.034337
#     Group selection probabilities:
#         Component: 0.554997
#         Concentration: 0.445003
#     Number of accepted moves: 75.
#     Fraction of accepted moves: 0.375000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.080000.
# ------
# TEMPERATURE: 0.030903
#     Group selection probabilities:
#         Component: 0.486198
#         Concentration: 0.513802
#     Number of accepted moves: 105.
#     Fraction of accepted moves: 0.525000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.123810.
# ------
# TEMPERATURE: 0.027813
#     Group selection probabilities:
#         Component: 0.465241
#         Concentration: 0.534759
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.405000.
#     Number of archive updates: 29.
#     Fraction of archive updates in accepted moves: 0.358025.
# ------
# TEMPERATURE: 0.025032
#     Group selection probabilities:
#         Component: 0.498589
#         Concentration: 0.501411
#     Number of accepted moves: 75.
#     Fraction of accepted moves: 0.375000.
#     Number of archive updates: 46.
#     Fraction of archive updates in accepted moves: 0.613333.
# ------
# TEMPERATURE: 0.022528
#     Group selection probabilities:
#         Component: 0.613668
#         Concentration: 0.386332
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.295000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.355932.
# ------
# TEMPERATURE: 0.020276
#     Group selection probabilities:
#         Component: 0.445195
#         Concentration: 0.554805
#     Number of accepted moves: 76.
#     Fraction of accepted moves: 0.380000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.263158.
# ------
# TEMPERATURE: 0.018248
#     Group selection probabilities:
#         Component: 0.451115
#         Concentration: 0.548885
#     Number of accepted moves: 73.
#     Fraction of accepted moves: 0.365000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.082192.
# ------
# TEMPERATURE: 0.016423
#     Group selection probabilities:
#         Component: 0.555749
#         Concentration: 0.444251
#     Number of accepted moves: 76.
#     Fraction of accepted moves: 0.380000.
#     Number of archive updates: 45.
#     Fraction of archive updates in accepted moves: 0.592105.
# ------
# TEMPERATURE: 0.014781
#     Group selection probabilities:
#         Component: 0.525359
#         Concentration: 0.474641
#     Number of accepted moves: 82.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 53.
#     Fraction of archive updates in accepted moves: 0.646341.
# ------
# TEMPERATURE: 0.013303
#     Group selection probabilities:
#         Component: 0.537713
#         Concentration: 0.462287
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.295000.
#     Number of archive updates: 48.
#     Fraction of archive updates in accepted moves: 0.813559.
# ------
# TEMPERATURE: 0.011973
#     Group selection probabilities:
#         Component: 0.462147
#         Concentration: 0.537853
#     Number of accepted moves: 68.
#     Fraction of accepted moves: 0.340000.
#     Number of archive updates: 34.
#     Fraction of archive updates in accepted moves: 0.500000.
# ------
# TEMPERATURE: 0.010775
#     Group selection probabilities:
#         Component: 0.482376
#         Concentration: 0.517624
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.295000.
#     Number of archive updates: 32.
#     Fraction of archive updates in accepted moves: 0.542373.
# ------
# TEMPERATURE: 0.009698
#     Group selection probabilities:
#         Component: 0.493557
#         Concentration: 0.506443
#     Number of accepted moves: 69.
#     Fraction of accepted moves: 0.345000.
#     Number of archive updates: 59.
#     Fraction of archive updates in accepted moves: 0.855072.
# ------
# TEMPERATURE: 0.008728
#     Group selection probabilities:
#         Component: 0.519967
#         Concentration: 0.480033
#     Number of accepted moves: 47.
#     Fraction of accepted moves: 0.235000.
#     Number of archive updates: 29.
#     Fraction of archive updates in accepted moves: 0.617021.
# ------
# TEMPERATURE: 0.007855
#     Group selection probabilities:
#         Component: 0.485632
#         Concentration: 0.514368
#     Number of accepted moves: 61.
#     Fraction of accepted moves: 0.305000.
#     Number of archive updates: 33.
#     Fraction of archive updates in accepted moves: 0.540984.
# ------
# TEMPERATURE: 0.007070
#     Group selection probabilities:
#         Component: 0.454099
#         Concentration: 0.545901
#     Number of accepted moves: 42.
#     Fraction of accepted moves: 0.210000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.071429.
# ------
# TEMPERATURE: 0.006363
#     Group selection probabilities:
#         Component: 0.578392
#         Concentration: 0.421608
#     Number of accepted moves: 31.
#     Fraction of accepted moves: 0.155000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.322581.
# ------
# TEMPERATURE: 0.005726
#     Group selection probabilities:
#         Component: 0.466024
#         Concentration: 0.533976
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.295000.
#     Number of archive updates: 40.
#     Fraction of archive updates in accepted moves: 0.677966.
# ------
# TEMPERATURE: 0.005154
#     Group selection probabilities:
#         Component: 0.459845
#         Concentration: 0.540155
#     Number of accepted moves: 63.
#     Fraction of accepted moves: 0.315000.
#     No archive update.
# ------
# TEMPERATURE: 0.004638
#     Group selection probabilities:
#         Component: 0.346213
#         Concentration: 0.653787
#     Number of accepted moves: 70.
#     Fraction of accepted moves: 0.350000.
#     No archive update.
# ------
# TEMPERATURE: 0.004175
#     Group selection probabilities:
#         Component: 0.441757
#         Concentration: 0.558243
#     Number of accepted moves: 54.
#     Fraction of accepted moves: 0.270000.
#     No archive update.
# ------
# TEMPERATURE: 0.003757
#     Group selection probabilities:
#         Component: 0.562246
#         Concentration: 0.437754
#     Number of accepted moves: 47.
#     Fraction of accepted moves: 0.235000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.042553.
# ------
# TEMPERATURE: 0.003381
#     Group selection probabilities:
#         Component: 0.467407
#         Concentration: 0.532593
#     Number of accepted moves: 31.
#     Fraction of accepted moves: 0.155000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.032258.
# ------
# TEMPERATURE: 0.003043
#     Group selection probabilities:
#         Component: 0.521951
#         Concentration: 0.478049
#     Number of accepted moves: 37.
#     Fraction of accepted moves: 0.185000.
#     No archive update.
# ------
# TEMPERATURE: 0.002739
#     Group selection probabilities:
#         Component: 0.627590
#         Concentration: 0.372410
#     Number of accepted moves: 35.
#     Fraction of accepted moves: 0.175000.
#     No archive update.
# ------
# TEMPERATURE: 0.002465
#     Group selection probabilities:
#         Component: 0.523454
#         Concentration: 0.476546
#     Number of accepted moves: 30.
#     Fraction of accepted moves: 0.150000.
#     No archive update.
# ------
# TEMPERATURE: 0.002219
#     Group selection probabilities:
#         Component: 0.548997
#         Concentration: 0.451003
#     Number of accepted moves: 29.
#     Fraction of accepted moves: 0.145000.
#     No archive update.
# ------
# TEMPERATURE: 0.001997
#     Group selection probabilities:
#         Component: 0.459561
#         Concentration: 0.540439
#     Insertion in the archive consecutively rejected 1000 times!
#     Stoping at iteration 94...
# ------
#
# --- THE END ---
# CPU times: total: 3.59 s
# Wall time: 4.69 s

# %% [markdown]
# ### Output 2

# %%
print(f"Number of solutions stored in the second archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the second archive: 1000

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.798806655167816, 14.351983156726249]
# Max: [-21.91711743864591, 222.00607715574202]
# Avg: [-27.187134271142646, 76.55278063901068]
# Std: [1.2651921438837552, 40.540737312948856]

# %%
opt.plot_front()

# %% [markdown]
# ### Run 3

# %%
# %%time
random.seed(3)
opt.archive_file = "archive3.json"
opt.evolve(fobj)
archive3 = opt.copyx()
# Out:
# --- BEGIN: Evolving a solution ---
#
# Initializing an empty archive...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     Component:
#         Number of elements: 2
#         Sample space: discrete
#         Size of population group: 26
#         Distinct elements: True
#         Selection probability: 0.459561
#         Weight of 'change value' trial move: 1.0
#         Weight of 'swap' trial move: 1.0
#         Sort values: False
#         Maximum step size: 13
#     Concentration:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,0.1)
#         Selection probability: 0.540439
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.05
# ------
# Initializing with a random solution from scratch...
# Done!
# ------
# TEMPERATURE: 1.000000
#     Number of accepted moves: 182.
#     Fraction of accepted moves: 0.910000.
#     Number of archive updates: 40.
#     Fraction of archive updates in accepted moves: 0.219780.
# ------
# TEMPERATURE: 0.900000
#     Group selection probabilities:
#         Component: 0.539879
#         Concentration: 0.460121
#     Number of accepted moves: 174.
#     Fraction of accepted moves: 0.870000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.097701.
# ------
# TEMPERATURE: 0.810000
#     Group selection probabilities:
#         Component: 0.583463
#         Concentration: 0.416537
#     Number of accepted moves: 172.
#     Fraction of accepted moves: 0.860000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.098837.
# ------
# TEMPERATURE: 0.729000
#     Group selection probabilities:
#         Component: 0.546796
#         Concentration: 0.453204
#     Number of accepted moves: 164.
#     Fraction of accepted moves: 0.820000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.085366.
# ------
# TEMPERATURE: 0.656100
#     Group selection probabilities:
#         Component: 0.624559
#         Concentration: 0.375441
#     Number of accepted moves: 146.
#     Fraction of accepted moves: 0.730000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.089041.
# ------
# TEMPERATURE: 0.590490
#     Group selection probabilities:
#         Component: 0.567079
#         Concentration: 0.432921
#     Number of accepted moves: 160.
#     Fraction of accepted moves: 0.800000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.018750.
# ------
# TEMPERATURE: 0.531441
#     Group selection probabilities:
#         Component: 0.621169
#         Concentration: 0.378831
#     Number of accepted moves: 152.
#     Fraction of accepted moves: 0.760000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.078947.
# ------
# TEMPERATURE: 0.478297
#     Group selection probabilities:
#         Component: 0.579760
#         Concentration: 0.420240
#     Number of accepted moves: 145.
#     Fraction of accepted moves: 0.725000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.055172.
# ------
# TEMPERATURE: 0.430467
#     Group selection probabilities:
#         Component: 0.571660
#         Concentration: 0.428340
#     Number of accepted moves: 136.
#     Fraction of accepted moves: 0.680000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.169118.
# ------
# TEMPERATURE: 0.387420
#     Group selection probabilities:
#         Component: 0.572156
#         Concentration: 0.427844
#     Number of accepted moves: 131.
#     Fraction of accepted moves: 0.655000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.038168.
# ------
# TEMPERATURE: 0.348678
#     Group selection probabilities:
#         Component: 0.551179
#         Concentration: 0.448821
#     Number of accepted moves: 136.
#     Fraction of accepted moves: 0.680000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.169118.
# ------
# TEMPERATURE: 0.313811
#     Group selection probabilities:
#         Component: 0.542852
#         Concentration: 0.457148
#     Number of accepted moves: 131.
#     Fraction of accepted moves: 0.655000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.030534.
# ------
# TEMPERATURE: 0.282430
#     Group selection probabilities:
#         Component: 0.638733
#         Concentration: 0.361267
#     Number of accepted moves: 121.
#     Fraction of accepted moves: 0.605000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.099174.
# ------
# TEMPERATURE: 0.254187
#     Group selection probabilities:
#         Component: 0.688522
#         Concentration: 0.311478
#     Number of accepted moves: 117.
#     Fraction of accepted moves: 0.585000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.153846.
# ------
# TEMPERATURE: 0.228768
#     Group selection probabilities:
#         Component: 0.634181
#         Concentration: 0.365819
#     Number of accepted moves: 128.
#     Fraction of accepted moves: 0.640000.
#     Number of archive updates: 16.
#     Fraction of archive updates in accepted moves: 0.125000.
# ------
# TEMPERATURE: 0.205891
#     Group selection probabilities:
#         Component: 0.605684
#         Concentration: 0.394316
#     Number of accepted moves: 123.
#     Fraction of accepted moves: 0.615000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.138211.
# ------
# TEMPERATURE: 0.185302
#     Group selection probabilities:
#         Component: 0.783350
#         Concentration: 0.216650
#     Number of accepted moves: 98.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.142857.
# ------
# TEMPERATURE: 0.166772
#     Group selection probabilities:
#         Component: 0.555850
#         Concentration: 0.444150
#     Number of accepted moves: 118.
#     Fraction of accepted moves: 0.590000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.016949.
# ------
# TEMPERATURE: 0.150095
#     Group selection probabilities:
#         Component: 0.534317
#         Concentration: 0.465683
#     Number of accepted moves: 134.
#     Fraction of accepted moves: 0.670000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.186567.
# ------
# TEMPERATURE: 0.135085
#     Group selection probabilities:
#         Component: 0.603231
#         Concentration: 0.396769
#     Number of accepted moves: 104.
#     Fraction of accepted moves: 0.520000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.096154.
# ------
# TEMPERATURE: 0.121577
#     Group selection probabilities:
#         Component: 0.587869
#         Concentration: 0.412131
#     Number of accepted moves: 103.
#     Fraction of accepted moves: 0.515000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.203883.
# ------
# TEMPERATURE: 0.109419
#     Group selection probabilities:
#         Component: 0.507424
#         Concentration: 0.492576
#     Number of accepted moves: 115.
#     Fraction of accepted moves: 0.575000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.052174.
# ------
# TEMPERATURE: 0.098477
#     Group selection probabilities:
#         Component: 0.519148
#         Concentration: 0.480852
#     Number of accepted moves: 105.
#     Fraction of accepted moves: 0.525000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.085714.
# ------
# TEMPERATURE: 0.088629
#     Group selection probabilities:
#         Component: 0.511492
#         Concentration: 0.488508
#     Number of accepted moves: 106.
#     Fraction of accepted moves: 0.530000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.188679.
# ------
# TEMPERATURE: 0.079766
#     Group selection probabilities:
#         Component: 0.550394
#         Concentration: 0.449606
#     Number of accepted moves: 107.
#     Fraction of accepted moves: 0.535000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.186916.
# ------
# TEMPERATURE: 0.071790
#     Group selection probabilities:
#         Component: 0.490025
#         Concentration: 0.509975
#     Number of accepted moves: 102.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.186275.
# ------
# TEMPERATURE: 0.064611
#     Group selection probabilities:
#         Component: 0.492175
#         Concentration: 0.507825
#     Number of accepted moves: 98.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 27.
#     Fraction of archive updates in accepted moves: 0.275510.
# ------
# TEMPERATURE: 0.058150
#     Group selection probabilities:
#         Component: 0.493888
#         Concentration: 0.506112
#     Number of accepted moves: 110.
#     Fraction of accepted moves: 0.550000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.090909.
# ------
# TEMPERATURE: 0.052335
#     Group selection probabilities:
#         Component: 0.472880
#         Concentration: 0.527120
#     Number of accepted moves: 108.
#     Fraction of accepted moves: 0.540000.
#     Number of archive updates: 42.
#     Fraction of archive updates in accepted moves: 0.388889.
# ------
# TEMPERATURE: 0.047101
#     Group selection probabilities:
#         Component: 0.489008
#         Concentration: 0.510992
#     Number of accepted moves: 101.
#     Fraction of accepted moves: 0.505000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.079208.
# ------
# TEMPERATURE: 0.042391
#     Group selection probabilities:
#         Component: 0.474868
#         Concentration: 0.525132
#     Number of accepted moves: 102.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.245098.
# ------
# TEMPERATURE: 0.038152
#     Group selection probabilities:
#         Component: 0.498755
#         Concentration: 0.501245
#     Number of accepted moves: 107.
#     Fraction of accepted moves: 0.535000.
#     Number of archive updates: 58.
#     Fraction of archive updates in accepted moves: 0.542056.
# ------
# TEMPERATURE: 0.034337
#     Group selection probabilities:
#         Component: 0.683973
#         Concentration: 0.316027
#     Number of accepted moves: 61.
#     Fraction of accepted moves: 0.305000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.377049.
# ------
# TEMPERATURE: 0.030903
#     Group selection probabilities:
#         Component: 0.545888
#         Concentration: 0.454112
#     Number of accepted moves: 74.
#     Fraction of accepted moves: 0.370000.
#     Number of archive updates: 24.
#     Fraction of archive updates in accepted moves: 0.324324.
# ------
# TEMPERATURE: 0.027813
#     Group selection probabilities:
#         Component: 0.567365
#         Concentration: 0.432635
#     Number of accepted moves: 67.
#     Fraction of accepted moves: 0.335000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.343284.
# ------
# TEMPERATURE: 0.025032
#     Group selection probabilities:
#         Component: 0.439375
#         Concentration: 0.560625
#     Number of accepted moves: 83.
#     Fraction of accepted moves: 0.415000.
#     Number of archive updates: 44.
#     Fraction of archive updates in accepted moves: 0.530120.
# ------
# TEMPERATURE: 0.022528
#     Group selection probabilities:
#         Component: 0.514168
#         Concentration: 0.485832
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.405000.
#     Number of archive updates: 56.
#     Fraction of archive updates in accepted moves: 0.691358.
# ------
# TEMPERATURE: 0.020276
#     Group selection probabilities:
#         Component: 0.672208
#         Concentration: 0.327792
#     Number of accepted moves: 73.
#     Fraction of accepted moves: 0.365000.
#     Number of archive updates: 46.
#     Fraction of archive updates in accepted moves: 0.630137.
# ------
# TEMPERATURE: 0.018248
#     Group selection probabilities:
#         Component: 0.562379
#         Concentration: 0.437621
#     Number of accepted moves: 64.
#     Fraction of accepted moves: 0.320000.
#     Number of archive updates: 26.
#     Fraction of archive updates in accepted moves: 0.406250.
# ------
# TEMPERATURE: 0.016423
#     Group selection probabilities:
#         Component: 0.464376
#         Concentration: 0.535624
#     Number of accepted moves: 69.
#     Fraction of accepted moves: 0.345000.
#     Number of archive updates: 35.
#     Fraction of archive updates in accepted moves: 0.507246.
# ------
# TEMPERATURE: 0.014781
#     Group selection probabilities:
#         Component: 0.465228
#         Concentration: 0.534772
#     Number of accepted moves: 68.
#     Fraction of accepted moves: 0.340000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.176471.
# ------
# TEMPERATURE: 0.013303
#     Group selection probabilities:
#         Component: 0.417559
#         Concentration: 0.582441
#     Number of accepted moves: 80.
#     Fraction of accepted moves: 0.400000.
#     Number of archive updates: 57.
#     Fraction of archive updates in accepted moves: 0.712500.
# ------
# TEMPERATURE: 0.011973
#     Group selection probabilities:
#         Component: 0.557964
#         Concentration: 0.442036
#     Number of accepted moves: 65.
#     Fraction of accepted moves: 0.325000.
#     Number of archive updates: 36.
#     Fraction of archive updates in accepted moves: 0.553846.
# ------
# TEMPERATURE: 0.010775
#     Group selection probabilities:
#         Component: 0.514503
#         Concentration: 0.485497
#     Number of accepted moves: 58.
#     Fraction of accepted moves: 0.290000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.258621.
# ------
# TEMPERATURE: 0.009698
#     Group selection probabilities:
#         Component: 0.483821
#         Concentration: 0.516179
#     Number of accepted moves: 49.
#     Fraction of accepted moves: 0.245000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.183673.
# ------
# TEMPERATURE: 0.008728
#     Group selection probabilities:
#         Component: 0.419280
#         Concentration: 0.580720
#     Number of accepted moves: 66.
#     Fraction of accepted moves: 0.330000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.378788.
# ------
# TEMPERATURE: 0.007855
#     Group selection probabilities:
#         Component: 0.493171
#         Concentration: 0.506829
#     Number of accepted moves: 63.
#     Fraction of accepted moves: 0.315000.
#     Number of archive updates: 29.
#     Fraction of archive updates in accepted moves: 0.460317.
# ------
# TEMPERATURE: 0.007070
#     Group selection probabilities:
#         Component: 0.449699
#         Concentration: 0.550301
#     Number of accepted moves: 53.
#     Fraction of accepted moves: 0.265000.
#     Number of archive updates: 30.
#     Fraction of archive updates in accepted moves: 0.566038.
# ------
# TEMPERATURE: 0.006363
#     Group selection probabilities:
#         Component: 0.504690
#         Concentration: 0.495310
#     Number of accepted moves: 44.
#     Fraction of accepted moves: 0.220000.
#     Number of archive updates: 34.
#     Fraction of archive updates in accepted moves: 0.772727.
# ------
# TEMPERATURE: 0.005726
#     Group selection probabilities:
#         Component: 0.438575
#         Concentration: 0.561425
#     Number of accepted moves: 44.
#     Fraction of accepted moves: 0.220000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.454545.
# ------
# TEMPERATURE: 0.005154
#     Group selection probabilities:
#         Component: 0.375964
#         Concentration: 0.624036
#     Number of accepted moves: 37.
#     Fraction of accepted moves: 0.185000.
#     No archive update.
# ------
# TEMPERATURE: 0.004638
#     Group selection probabilities:
#         Component: 0.506796
#         Concentration: 0.493204
#     Number of accepted moves: 34.
#     Fraction of accepted moves: 0.170000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.264706.
# ------
# TEMPERATURE: 0.004175
#     Group selection probabilities:
#         Component: 0.550561
#         Concentration: 0.449439
#     Number of accepted moves: 45.
#     Fraction of accepted moves: 0.225000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.133333.
# ------
# TEMPERATURE: 0.003757
#     Group selection probabilities:
#         Component: 0.450886
#         Concentration: 0.549114
#     Number of accepted moves: 34.
#     Fraction of accepted moves: 0.170000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.147059.
# ------
# TEMPERATURE: 0.003381
#     Group selection probabilities:
#         Component: 0.497201
#         Concentration: 0.502799
#     Number of accepted moves: 44.
#     Fraction of accepted moves: 0.220000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.045455.
# ------
# TEMPERATURE: 0.003043
#     Group selection probabilities:
#         Component: 0.550343
#         Concentration: 0.449657
#     Number of accepted moves: 33.
#     Fraction of accepted moves: 0.165000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.090909.
# ------
# TEMPERATURE: 0.002739
#     Group selection probabilities:
#         Component: 0.397488
#         Concentration: 0.602512
#     Number of accepted moves: 61.
#     Fraction of accepted moves: 0.305000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.016393.
# ------
# TEMPERATURE: 0.002465
#     Group selection probabilities:
#         Component: 0.441855
#         Concentration: 0.558145
#     Number of accepted moves: 30.
#     Fraction of accepted moves: 0.150000.
#     No archive update.
# ------
# TEMPERATURE: 0.002219
#     Group selection probabilities:
#         Component: 0.378612
#         Concentration: 0.621388
#     Number of accepted moves: 40.
#     Fraction of accepted moves: 0.200000.
#     No archive update.
# ------
# TEMPERATURE: 0.001997
#     Group selection probabilities:
#         Component: 0.434701
#         Concentration: 0.565299
#     Number of accepted moves: 34.
#     Fraction of accepted moves: 0.170000.
#     No archive update.
# ------
# TEMPERATURE: 0.001797
#     Group selection probabilities:
#         Component: 0.344503
#         Concentration: 0.655497
#     Number of accepted moves: 34.
#     Fraction of accepted moves: 0.170000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.029412.
# ------
# TEMPERATURE: 0.001617
#     Group selection probabilities:
#         Component: 0.364273
#         Concentration: 0.635727
#     Number of accepted moves: 33.
#     Fraction of accepted moves: 0.165000.
#     No archive update.
# ------
# TEMPERATURE: 0.001456
#     Group selection probabilities:
#         Component: 0.451237
#         Concentration: 0.548763
#     Number of accepted moves: 32.
#     Fraction of accepted moves: 0.160000.
#     No archive update.
# ------
# TEMPERATURE: 0.001310
#     Group selection probabilities:
#         Component: 0.394277
#         Concentration: 0.605723
#     Number of accepted moves: 35.
#     Fraction of accepted moves: 0.175000.
#     No archive update.
# ------
# TEMPERATURE: 0.001179
#     Group selection probabilities:
#         Component: 0.433995
#         Concentration: 0.566005
#     Number of accepted moves: 8.
#     Fraction of accepted moves: 0.040000.
#     No archive update.
# ------
# TEMPERATURE: 0.001061
#     Group selection probabilities:
#         Component: 0.487860
#         Concentration: 0.512140
#     Insertion in the archive consecutively rejected 1000 times!
#     Stoping at iteration 109...
# ------
#
# --- THE END ---
# CPU times: total: 3.64 s
# Wall time: 5.21 s

# %% [markdown]
# ### Output 3

# %%
print(f"Number of solutions stored in the third archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the third archive: 1000

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.798914722131478, 14.33707848405619]
# Max: [-21.91941828787721, 222.02156498457177]
# Avg: [-27.512675816952058, 88.37991414697866]
# Std: [1.0380063912550175, 45.90812404060142]

# %%
opt.plot_front()

# %% [markdown]
# ### Merges the three solution archives and removes the dominated solutions from the resulting archive
#
# Merging archives from different runs provides a simple manner of performing parallel runs.

# %%
# %%time
merged = opt.mergex([archive1, archive2, archive3])
pruned = opt.prune_dominated(xset=merged)
opt.savex(xset=pruned, archive_file="merged_archive.json")
# Out:
# CPU times: total: 1.73 s
# Wall time: 11 s

# %%
print(f"Number of solutions stored in the merged archive: {opt.sizex(pruned)}")
# Out:
# Number of solutions stored in the merged archive: 2837

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.798914722131478, 14.33707848405619]
# Max: [-21.91941828787721, 222.02156498457177]
# Avg: [-27.512675816952058, 88.37991414697866]
# Std: [1.0380063912550175, 45.90812404060142]

# %%
opt.plot_front(pruned)

# %% [markdown]
# ### Decision making
#
# Many solutions (i.e., candidate alloys) still remain in the archive and it is hard to choose one or two out of them.
#
# In order to reduce the solution set to something a human being is able to deal with, first, the *trimx* method is
# used to select only the alloys that present a reasonable (according to the users needs) value of the *X* property.

# %%
trimmed = opt.trimx(xset=pruned, thresholds=[-27.0, None])
print(f"Number of solutions stored in the reduced archive: {opt.sizex(trimmed)}")
# Out:
# Number of solutions stored in the reduced archive: 2540

# %% [markdown]
# The next step is to further reduce the number of solutions. Below, we use the *reducex* method to select 10 alloying candidates with the lowest cost, assuming cost is the most important variable for the user.
#
# As can be seen, **V** alloys with more than 9\% **I** added as an alloying element are the optimized alloys considering the user needs.

# %%
sol1 = opt.reducex(xset=trimmed, index=1, nel=10)
opt.printx(sol1)
# Out:
# 0) Component: [V, I], Concentration: 0.09828379384216755 ===> [-27.03778864367842, 63.46032410952731]
# 1) Component: [V, I], Concentration: 0.09785017725370286 ===> [-27.040250492761537, 63.483963830561045]
# 2) Component: [V, I], Concentration: 0.09712628936557093 ===> [-27.04436035105821, 63.52342843636803]
# 3) Component: [V, I], Concentration: 0.09709913083332432 ===> [-27.044514543055215, 63.52490905344558]
# 4) Component: [V, I], Concentration: 0.09689201421234878 ===> [-27.045690443325203, 63.53620054752483]
# 5) Component: [V, I], Concentration: 0.0965675319515005 ===> [-27.04753268455307, 63.553890530636416]
# 6) Component: [V, I], Concentration: 0.09427694773629285 ===> [-27.0605374283752, 63.678767607049664]
# 7) Component: [V, I], Concentration: 0.09392976045614035 ===> [-27.062508576873782, 63.69769541255249]
# 8) Component: [V, I], Concentration: 0.09285816701375287 ===> [-27.068592526159385, 63.756116078904995]
# 9) Component: [V, I], Concentration: 0.09275222835767127 ===> [-27.069193990656544, 63.76189159659292]

# %% [markdown]
# To reduce the number of candidates even further, we use the *reducex* method again, but now to select 5 alloy candidates with the highest value of the *X* property.

# %%
sol2 = opt.reducex(xset=sol1, index=0, nel=5)
opt.printx(sol2)
# Out:
# 0) Component: [V, I], Concentration: 0.09275222835767127 ===> [-27.069193990656544, 63.76189159659292]
# 1) Component: [V, I], Concentration: 0.09285816701375287 ===> [-27.068592526159385, 63.756116078904995]
# 2) Component: [V, I], Concentration: 0.09392976045614035 ===> [-27.062508576873782, 63.69769541255249]
# 3) Component: [V, I], Concentration: 0.09427694773629285 ===> [-27.0605374283752, 63.678767607049664]
# 4) Component: [V, I], Concentration: 0.0965675319515005 ===> [-27.04753268455307, 63.553890530636416]

# %% [markdown]
# As an alternative to manually reducing the archive in multiple steps, we can use the *bestx* method to select a single candidate alloy by means of the TOPSIS decision-making criterion.

# %%
best_alloy = opt.bestx(xset=trimmed)
opt.printx(best_alloy)
# Out:
# 0) Component: [V, R], Concentration: 0.09992809330887281 ===> [-27.41265524468137, 65.42027177517922]
