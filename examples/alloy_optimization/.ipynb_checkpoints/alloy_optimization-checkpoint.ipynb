# %% [markdown]
# ## Alloy optimization
#
# Using a toy model, multi-objective optimization is employed to select the cheapest alloys exhibiting enhanced *X* property after mixing.

# %%
import mosa
from numpy import random, arange, asarray

# %matplotlib inline

# %%
random.seed(0)

# %% [markdown]
# The pure, fictitious elements have symbols in the **A**...**Z** range. The *X* property and the cost associated with the pure elements was generated by the *generate_data* function below.

# %%
def generate_data(component):
    k = arange(component.shape[0]) + 1

    x0 = 0.5
    x1 = 12.6
    x = x0 * k + x1 + random.uniform(0.0, 5.0, component.shape[0])

    cost = random.uniform(5.0, 500.0, component.shape[0])

    return x, cost

# %% [markdown]
# ### Translating the alloy optimization problem into Python code
#
# The function *fobj* below implements the problem. The two objectives to be minimized are the *X* property and the final cost of the proposed alloy.
#
# The solution to the problem consists of two groups. "Component" is a list, where the first element is the matrix element and the second is the alloying element. "Concentration" gives the relative amount of the alloying element in the alloy.
#
# Notice that both *X* and cost of the alloy results from a simple mixing rule considering *X* and cost of the pure elements.
#
# Also, maximizing *X* is equivalent to minimizing -*X*, that is why -*x* is returned by *fobj*.

# %%
def fobj(Component: list, Concentration: float) -> tuple:
    first, second = Component

    x1 = float(X[component == first][0])
    cost1 = float(Cost[component == first][0])

    x2 = float(X[component == second][0])
    cost2 = float(Cost[component == second][0])

    x = x1 * (1.0 - Concentration) + x2 * Concentration
    cost = cost1 * (1.0 - Concentration) + cost2 * Concentration

    return -x, cost

# %%
component = asarray(list("ABCDEFGHIJKLMNOPQRSTUVWXYZ"))

# %%
X, Cost = generate_data(component)

# %% [markdown]
# ### Initialization

# %%
opt = mosa.Anneal()
# Out:
# --------------------------------------------------
#  MULTI-OBJECTIVE SIMULATED ANNEALING (MOSA) 0.9.1
# --------------------------------------------------

# %%
opt.set_population(Component=component.tolist(), Concentration=(0.0, 0.1))

# %%
opt.initial_temperature = 1.0
opt.number_of_temperatures = 100
opt.number_of_iterations = 200
opt.objective_weights = [(X.max() - X.min()), (Cost.max() - Cost.min())]
opt.archive_size = 1000
opt.maximum_archive_rejections = 1000

# %%
opt.set_opt_param("number_of_elements", Component=2, Concentration=1)
opt.set_opt_param("group_selection_weights", Component=1.0, Concentration=4.0)
opt.set_opt_param("distinct_elements", Component=True)
opt.set_opt_param("change_value_move", Component=1.0, Concentration=1.0)
opt.set_opt_param("swap_move", Component=1.0)
opt.set_opt_param("mc_step_size", Concentration=0.05)

# %%
opt.verbose = True

# %% [markdown]
# IMPORTANT: Restarting from previous runs is disabled.

# %%
opt.restart = False

# %% [markdown]
# ### Run 1

# %%
# %%time
random.seed(1)
opt.archive_file = "archive1.json"
opt.evolve(fobj)
archive1 = opt.copyx()
# Out:
# --- BEGIN: Evolving a solution ---
#
# Initializing an empty archive...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     Component:
#         Number of elements: 2
#         Sample space: discrete
#         Size of population group: 26
#         Distinct elements: True
#         Selection weight: 1.0
#         Weight of 'change value' trial move: 1.0
#         Weight of 'swap' trial move: 1.0
#         Sort values: False
#         Maximum step size: 13
#     Concentration:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,0.1)
#         Selection weight: 4.0
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.05
# ------
# Initializing with a random solution from scratch...
# Done!
# ------
# TEMPERATURE: 1.000000
#     Number of accepted moves: 189.
#     Fraction of accepted moves: 0.945000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.121693.
# ------
# TEMPERATURE: 0.900000
#     Number of accepted moves: 188.
#     Fraction of accepted moves: 0.940000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.101064.
# ------
# TEMPERATURE: 0.810000
#     Number of accepted moves: 193.
#     Fraction of accepted moves: 0.965000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.025907.
# ------
# TEMPERATURE: 0.729000
#     Number of accepted moves: 186.
#     Fraction of accepted moves: 0.930000.
#     Number of archive updates: 63.
#     Fraction of archive updates in accepted moves: 0.338710.
# ------
# TEMPERATURE: 0.656100
#     Number of accepted moves: 190.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 75.
#     Fraction of archive updates in accepted moves: 0.394737.
# ------
# TEMPERATURE: 0.590490
#     Number of accepted moves: 175.
#     Fraction of accepted moves: 0.875000.
#     Number of archive updates: 50.
#     Fraction of archive updates in accepted moves: 0.285714.
# ------
# TEMPERATURE: 0.531441
#     Number of accepted moves: 166.
#     Fraction of accepted moves: 0.830000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.114458.
# ------
# TEMPERATURE: 0.478297
#     Number of accepted moves: 175.
#     Fraction of accepted moves: 0.875000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.062857.
# ------
# TEMPERATURE: 0.430467
#     Number of accepted moves: 179.
#     Fraction of accepted moves: 0.895000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.067039.
# ------
# TEMPERATURE: 0.387420
#     Number of accepted moves: 184.
#     Fraction of accepted moves: 0.920000.
#     No archive update.
# ------
# TEMPERATURE: 0.348678
#     Number of accepted moves: 184.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 57.
#     Fraction of archive updates in accepted moves: 0.309783.
# ------
# TEMPERATURE: 0.313811
#     Number of accepted moves: 161.
#     Fraction of accepted moves: 0.805000.
#     Number of archive updates: 30.
#     Fraction of archive updates in accepted moves: 0.186335.
# ------
# TEMPERATURE: 0.282430
#     Number of accepted moves: 176.
#     Fraction of accepted moves: 0.880000.
#     Number of archive updates: 35.
#     Fraction of archive updates in accepted moves: 0.198864.
# ------
# TEMPERATURE: 0.254187
#     Number of accepted moves: 170.
#     Fraction of accepted moves: 0.850000.
#     No archive update.
# ------
# TEMPERATURE: 0.228768
#     Number of accepted moves: 163.
#     Fraction of accepted moves: 0.815000.
#     No archive update.
# ------
# TEMPERATURE: 0.205891
#     Number of accepted moves: 162.
#     Fraction of accepted moves: 0.810000.
#     No archive update.
# ------
# TEMPERATURE: 0.185302
#     Number of accepted moves: 164.
#     Fraction of accepted moves: 0.820000.
#     Number of archive updates: 82.
#     Fraction of archive updates in accepted moves: 0.500000.
# ------
# TEMPERATURE: 0.166772
#     Number of accepted moves: 168.
#     Fraction of accepted moves: 0.840000.
#     Number of archive updates: 51.
#     Fraction of archive updates in accepted moves: 0.303571.
# ------
# TEMPERATURE: 0.150095
#     Number of accepted moves: 169.
#     Fraction of accepted moves: 0.845000.
#     Number of archive updates: 32.
#     Fraction of archive updates in accepted moves: 0.189349.
# ------
# TEMPERATURE: 0.135085
#     Number of accepted moves: 150.
#     Fraction of accepted moves: 0.750000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.133333.
# ------
# TEMPERATURE: 0.121577
#     Number of accepted moves: 157.
#     Fraction of accepted moves: 0.785000.
#     Number of archive updates: 61.
#     Fraction of archive updates in accepted moves: 0.388535.
# ------
# TEMPERATURE: 0.109419
#     Number of accepted moves: 149.
#     Fraction of accepted moves: 0.745000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.033557.
# ------
# TEMPERATURE: 0.098477
#     Number of accepted moves: 153.
#     Fraction of accepted moves: 0.765000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.026144.
# ------
# TEMPERATURE: 0.088629
#     Number of accepted moves: 155.
#     Fraction of accepted moves: 0.775000.
#     Number of archive updates: 50.
#     Fraction of archive updates in accepted moves: 0.322581.
# ------
# TEMPERATURE: 0.079766
#     Number of accepted moves: 126.
#     Fraction of accepted moves: 0.630000.
#     No archive update.
# ------
# TEMPERATURE: 0.071790
#     Number of accepted moves: 138.
#     Fraction of accepted moves: 0.690000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.021739.
# ------
# TEMPERATURE: 0.064611
#     Number of accepted moves: 132.
#     Fraction of accepted moves: 0.660000.
#     Number of archive updates: 36.
#     Fraction of archive updates in accepted moves: 0.272727.
# ------
# TEMPERATURE: 0.058150
#     Number of accepted moves: 146.
#     Fraction of accepted moves: 0.730000.
#     Number of archive updates: 27.
#     Fraction of archive updates in accepted moves: 0.184932.
# ------
# TEMPERATURE: 0.052335
#     Number of accepted moves: 123.
#     Fraction of accepted moves: 0.615000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.081301.
# ------
# TEMPERATURE: 0.047101
#     Number of accepted moves: 131.
#     Fraction of accepted moves: 0.655000.
#     No archive update.
# ------
# TEMPERATURE: 0.042391
#     Number of accepted moves: 131.
#     Fraction of accepted moves: 0.655000.
#     No archive update.
# ------
# TEMPERATURE: 0.038152
#     Number of accepted moves: 134.
#     Fraction of accepted moves: 0.670000.
#     Number of archive updates: 53.
#     Fraction of archive updates in accepted moves: 0.395522.
# ------
# TEMPERATURE: 0.034337
#     Number of accepted moves: 114.
#     Fraction of accepted moves: 0.570000.
#     Number of archive updates: 42.
#     Fraction of archive updates in accepted moves: 0.368421.
# ------
# TEMPERATURE: 0.030903
#     Number of accepted moves: 83.
#     Fraction of accepted moves: 0.415000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.240964.
# ------
# TEMPERATURE: 0.027813
#     Number of accepted moves: 113.
#     Fraction of accepted moves: 0.565000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.274336.
# ------
# TEMPERATURE: 0.025032
#     Number of accepted moves: 119.
#     Fraction of accepted moves: 0.595000.
#     No archive update.
# ------
# TEMPERATURE: 0.022528
#     Number of accepted moves: 70.
#     Fraction of accepted moves: 0.350000.
#     No archive update.
# ------
# TEMPERATURE: 0.020276
#     Number of accepted moves: 74.
#     Fraction of accepted moves: 0.370000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.081081.
# ------
# TEMPERATURE: 0.018248
#     Number of accepted moves: 140.
#     Fraction of accepted moves: 0.700000.
#     Number of archive updates: 118.
#     Fraction of archive updates in accepted moves: 0.842857.
# ------
# TEMPERATURE: 0.016423
#     Number of accepted moves: 122.
#     Fraction of accepted moves: 0.610000.
#     Number of archive updates: 57.
#     Fraction of archive updates in accepted moves: 0.467213.
# ------
# TEMPERATURE: 0.014781
#     Number of accepted moves: 155.
#     Fraction of accepted moves: 0.775000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.006452.
# ------
# TEMPERATURE: 0.013303
#     Number of accepted moves: 98.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.061224.
# ------
# TEMPERATURE: 0.011973
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.405000.
#     No archive update.
# ------
# TEMPERATURE: 0.010775
#     Number of accepted moves: 97.
#     Fraction of accepted moves: 0.485000.
#     No archive update.
# ------
# TEMPERATURE: 0.009698
#     Number of accepted moves: 53.
#     Fraction of accepted moves: 0.265000.
#     No archive update.
# ------
# TEMPERATURE: 0.008728
#     Number of accepted moves: 99.
#     Fraction of accepted moves: 0.495000.
#     No archive update.
# ------
# TEMPERATURE: 0.007855
#     Insertion in the archive consecutively rejected 1000 times!
#     Stoping at iteration 85...
# ------
#
# --- THE END ---
# CPU times: total: 953 ms
# Wall time: 1.41 s

# %% [markdown]
# ### Output 1

# %%
print(f"Number of solutions stored in the first archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the first archive: 1000

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.798964717583722, 14.311593764246744]
# Max: [-21.92030878072173, 222.0914274334782]
# Avg: [-27.06807966767453, 87.0164976861366]
# Std: [1.6923674214294513, 53.84203952481141]

# %%
opt.plot_front()

# %% [markdown]
# ### Run 2

# %%
# %%time
random.seed(2)
opt.archive_file = "archive2.json"
opt.evolve(fobj)
archive2 = opt.copyx()
# Out:
# --- BEGIN: Evolving a solution ---
#
# Initializing an empty archive...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     Component:
#         Number of elements: 2
#         Sample space: discrete
#         Size of population group: 26
#         Distinct elements: True
#         Selection weight: 1.0
#         Weight of 'change value' trial move: 1.0
#         Weight of 'swap' trial move: 1.0
#         Sort values: False
#         Maximum step size: 13
#     Concentration:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,0.1)
#         Selection weight: 4.0
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.05
# ------
# Initializing with a random solution from scratch...
# Done!
# ------
# TEMPERATURE: 1.000000
#     Number of accepted moves: 193.
#     Fraction of accepted moves: 0.965000.
#     Number of archive updates: 59.
#     Fraction of archive updates in accepted moves: 0.305699.
# ------
# TEMPERATURE: 0.900000
#     Number of accepted moves: 187.
#     Fraction of accepted moves: 0.935000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.053476.
# ------
# TEMPERATURE: 0.810000
#     Number of accepted moves: 190.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.021053.
# ------
# TEMPERATURE: 0.729000
#     Number of accepted moves: 190.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.015789.
# ------
# TEMPERATURE: 0.656100
#     Number of accepted moves: 194.
#     Fraction of accepted moves: 0.970000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.030928.
# ------
# TEMPERATURE: 0.590490
#     Number of accepted moves: 181.
#     Fraction of accepted moves: 0.905000.
#     No archive update.
# ------
# TEMPERATURE: 0.531441
#     Number of accepted moves: 176.
#     Fraction of accepted moves: 0.880000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.085227.
# ------
# TEMPERATURE: 0.478297
#     Number of accepted moves: 192.
#     Fraction of accepted moves: 0.960000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.072917.
# ------
# TEMPERATURE: 0.430467
#     Number of accepted moves: 172.
#     Fraction of accepted moves: 0.860000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.063953.
# ------
# TEMPERATURE: 0.387420
#     Number of accepted moves: 178.
#     Fraction of accepted moves: 0.890000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.044944.
# ------
# TEMPERATURE: 0.348678
#     Number of accepted moves: 176.
#     Fraction of accepted moves: 0.880000.
#     No archive update.
# ------
# TEMPERATURE: 0.313811
#     Number of accepted moves: 164.
#     Fraction of accepted moves: 0.820000.
#     Number of archive updates: 38.
#     Fraction of archive updates in accepted moves: 0.231707.
# ------
# TEMPERATURE: 0.282430
#     Number of accepted moves: 172.
#     Fraction of accepted moves: 0.860000.
#     Number of archive updates: 56.
#     Fraction of archive updates in accepted moves: 0.325581.
# ------
# TEMPERATURE: 0.254187
#     Number of accepted moves: 170.
#     Fraction of accepted moves: 0.850000.
#     Number of archive updates: 40.
#     Fraction of archive updates in accepted moves: 0.235294.
# ------
# TEMPERATURE: 0.228768
#     Number of accepted moves: 169.
#     Fraction of accepted moves: 0.845000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.106509.
# ------
# TEMPERATURE: 0.205891
#     Number of accepted moves: 158.
#     Fraction of accepted moves: 0.790000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.139241.
# ------
# TEMPERATURE: 0.185302
#     Number of accepted moves: 164.
#     Fraction of accepted moves: 0.820000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.054878.
# ------
# TEMPERATURE: 0.166772
#     Number of accepted moves: 162.
#     Fraction of accepted moves: 0.810000.
#     Number of archive updates: 47.
#     Fraction of archive updates in accepted moves: 0.290123.
# ------
# TEMPERATURE: 0.150095
#     Number of accepted moves: 158.
#     Fraction of accepted moves: 0.790000.
#     Number of archive updates: 66.
#     Fraction of archive updates in accepted moves: 0.417722.
# ------
# TEMPERATURE: 0.135085
#     Number of accepted moves: 161.
#     Fraction of accepted moves: 0.805000.
#     Number of archive updates: 108.
#     Fraction of archive updates in accepted moves: 0.670807.
# ------
# TEMPERATURE: 0.121577
#     Number of accepted moves: 149.
#     Fraction of accepted moves: 0.745000.
#     No archive update.
# ------
# TEMPERATURE: 0.109419
#     Number of accepted moves: 139.
#     Fraction of accepted moves: 0.695000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.021583.
# ------
# TEMPERATURE: 0.098477
#     Number of accepted moves: 162.
#     Fraction of accepted moves: 0.810000.
#     Number of archive updates: 56.
#     Fraction of archive updates in accepted moves: 0.345679.
# ------
# TEMPERATURE: 0.088629
#     Number of accepted moves: 152.
#     Fraction of accepted moves: 0.760000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.118421.
# ------
# TEMPERATURE: 0.079766
#     Number of accepted moves: 153.
#     Fraction of accepted moves: 0.765000.
#     Number of archive updates: 78.
#     Fraction of archive updates in accepted moves: 0.509804.
# ------
# TEMPERATURE: 0.071790
#     Number of accepted moves: 115.
#     Fraction of accepted moves: 0.575000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.060870.
# ------
# TEMPERATURE: 0.064611
#     Number of accepted moves: 155.
#     Fraction of accepted moves: 0.775000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.200000.
# ------
# TEMPERATURE: 0.058150
#     Number of accepted moves: 134.
#     Fraction of accepted moves: 0.670000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.007463.
# ------
# TEMPERATURE: 0.052335
#     Number of accepted moves: 111.
#     Fraction of accepted moves: 0.555000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.009009.
# ------
# TEMPERATURE: 0.047101
#     Number of accepted moves: 137.
#     Fraction of accepted moves: 0.685000.
#     Number of archive updates: 40.
#     Fraction of archive updates in accepted moves: 0.291971.
# ------
# TEMPERATURE: 0.042391
#     Number of accepted moves: 122.
#     Fraction of accepted moves: 0.610000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.008197.
# ------
# TEMPERATURE: 0.038152
#     Number of accepted moves: 120.
#     Fraction of accepted moves: 0.600000.
#     Number of archive updates: 49.
#     Fraction of archive updates in accepted moves: 0.408333.
# ------
# TEMPERATURE: 0.034337
#     Number of accepted moves: 120.
#     Fraction of accepted moves: 0.600000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.066667.
# ------
# TEMPERATURE: 0.030903
#     Number of accepted moves: 122.
#     Fraction of accepted moves: 0.610000.
#     Number of archive updates: 45.
#     Fraction of archive updates in accepted moves: 0.368852.
# ------
# TEMPERATURE: 0.027813
#     Number of accepted moves: 116.
#     Fraction of accepted moves: 0.580000.
#     Number of archive updates: 62.
#     Fraction of archive updates in accepted moves: 0.534483.
# ------
# TEMPERATURE: 0.025032
#     Number of accepted moves: 114.
#     Fraction of accepted moves: 0.570000.
#     Number of archive updates: 67.
#     Fraction of archive updates in accepted moves: 0.587719.
# ------
# TEMPERATURE: 0.022528
#     Number of accepted moves: 126.
#     Fraction of accepted moves: 0.630000.
#     Number of archive updates: 110.
#     Fraction of archive updates in accepted moves: 0.873016.
# ------
# TEMPERATURE: 0.020276
#     Number of accepted moves: 77.
#     Fraction of accepted moves: 0.385000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.142857.
# ------
# TEMPERATURE: 0.018248
#     Number of accepted moves: 111.
#     Fraction of accepted moves: 0.555000.
#     No archive update.
# ------
# TEMPERATURE: 0.016423
#     Number of accepted moves: 69.
#     Fraction of accepted moves: 0.345000.
#     No archive update.
# ------
# TEMPERATURE: 0.014781
#     Number of accepted moves: 78.
#     Fraction of accepted moves: 0.390000.
#     Number of archive updates: 45.
#     Fraction of archive updates in accepted moves: 0.576923.
# ------
# TEMPERATURE: 0.013303
#     Number of accepted moves: 113.
#     Fraction of accepted moves: 0.565000.
#     Number of archive updates: 82.
#     Fraction of archive updates in accepted moves: 0.725664.
# ------
# TEMPERATURE: 0.011973
#     Number of accepted moves: 77.
#     Fraction of accepted moves: 0.385000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.142857.
# ------
# TEMPERATURE: 0.010775
#     Number of accepted moves: 86.
#     Fraction of accepted moves: 0.430000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.034884.
# ------
# TEMPERATURE: 0.009698
#     Number of accepted moves: 86.
#     Fraction of accepted moves: 0.430000.
#     No archive update.
# ------
# TEMPERATURE: 0.008728
#     Number of accepted moves: 102.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.049020.
# ------
# TEMPERATURE: 0.007855
#     Number of accepted moves: 70.
#     Fraction of accepted moves: 0.350000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.028571.
# ------
# TEMPERATURE: 0.007070
#     Number of accepted moves: 104.
#     Fraction of accepted moves: 0.520000.
#     No archive update.
# ------
# TEMPERATURE: 0.006363
#     Number of accepted moves: 91.
#     Fraction of accepted moves: 0.455000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.010989.
# ------
# TEMPERATURE: 0.005726
#     Number of accepted moves: 62.
#     Fraction of accepted moves: 0.310000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.016129.
# ------
# TEMPERATURE: 0.005154
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.295000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.101695.
# ------
# TEMPERATURE: 0.004638
#     Number of accepted moves: 55.
#     Fraction of accepted moves: 0.275000.
#     No archive update.
# ------
# TEMPERATURE: 0.004175
#     Number of accepted moves: 34.
#     Fraction of accepted moves: 0.170000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.029412.
# ------
# TEMPERATURE: 0.003757
#     Number of accepted moves: 29.
#     Fraction of accepted moves: 0.145000.
#     No archive update.
# ------
# TEMPERATURE: 0.003381
#     Number of accepted moves: 56.
#     Fraction of accepted moves: 0.280000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.071429.
# ------
# TEMPERATURE: 0.003043
#     Number of accepted moves: 24.
#     Fraction of accepted moves: 0.120000.
#     No archive update.
# ------
# TEMPERATURE: 0.002739
#     Number of accepted moves: 36.
#     Fraction of accepted moves: 0.180000.
#     No archive update.
# ------
# TEMPERATURE: 0.002465
#     Number of accepted moves: 79.
#     Fraction of accepted moves: 0.395000.
#     No archive update.
# ------
# TEMPERATURE: 0.002219
#     Number of accepted moves: 26.
#     Fraction of accepted moves: 0.130000.
#     No archive update.
# ------
# TEMPERATURE: 0.001997
#     Insertion in the archive consecutively rejected 1000 times!
#     Stoping at iteration 150...
# ------
#
# --- THE END ---
# CPU times: total: 1.02 s
# Wall time: 1.54 s

# %% [markdown]
# ### Output 2

# %%
print(f"Number of solutions stored in the second archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the second archive: 1000

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.795613790192576, 14.320338781109934]
# Max: [-21.918906520505097, 221.86155890560028]
# Avg: [-27.255098744413942, 75.11679590691351]
# Std: [0.9584454700238314, 37.8087748724682]

# %%
opt.plot_front()

# %% [markdown]
# ### Run 3

# %%
# %%time
random.seed(3)
opt.archive_file = "archive3.json"
opt.evolve(fobj)
archive3 = opt.copyx()
# Out:
# --- BEGIN: Evolving a solution ---
#
# Initializing an empty archive...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     Component:
#         Number of elements: 2
#         Sample space: discrete
#         Size of population group: 26
#         Distinct elements: True
#         Selection weight: 1.0
#         Weight of 'change value' trial move: 1.0
#         Weight of 'swap' trial move: 1.0
#         Sort values: False
#         Maximum step size: 13
#     Concentration:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,0.1)
#         Selection weight: 4.0
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.05
# ------
# Initializing with a random solution from scratch...
# Done!
# ------
# TEMPERATURE: 1.000000
#     Number of accepted moves: 193.
#     Fraction of accepted moves: 0.965000.
#     Number of archive updates: 26.
#     Fraction of archive updates in accepted moves: 0.134715.
# ------
# TEMPERATURE: 0.900000
#     Number of accepted moves: 190.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 28.
#     Fraction of archive updates in accepted moves: 0.147368.
# ------
# TEMPERATURE: 0.810000
#     Number of accepted moves: 189.
#     Fraction of accepted moves: 0.945000.
#     Number of archive updates: 45.
#     Fraction of archive updates in accepted moves: 0.238095.
# ------
# TEMPERATURE: 0.729000
#     Number of accepted moves: 190.
#     Fraction of accepted moves: 0.950000.
#     No archive update.
# ------
# TEMPERATURE: 0.656100
#     Number of accepted moves: 187.
#     Fraction of accepted moves: 0.935000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.016043.
# ------
# TEMPERATURE: 0.590490
#     Number of accepted moves: 184.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.038043.
# ------
# TEMPERATURE: 0.531441
#     Number of accepted moves: 177.
#     Fraction of accepted moves: 0.885000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.062147.
# ------
# TEMPERATURE: 0.478297
#     Number of accepted moves: 186.
#     Fraction of accepted moves: 0.930000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.021505.
# ------
# TEMPERATURE: 0.430467
#     Number of accepted moves: 176.
#     Fraction of accepted moves: 0.880000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.039773.
# ------
# TEMPERATURE: 0.387420
#     Number of accepted moves: 178.
#     Fraction of accepted moves: 0.890000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.123596.
# ------
# TEMPERATURE: 0.348678
#     Number of accepted moves: 175.
#     Fraction of accepted moves: 0.875000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.017143.
# ------
# TEMPERATURE: 0.313811
#     Number of accepted moves: 181.
#     Fraction of accepted moves: 0.905000.
#     Number of archive updates: 55.
#     Fraction of archive updates in accepted moves: 0.303867.
# ------
# TEMPERATURE: 0.282430
#     Number of accepted moves: 175.
#     Fraction of accepted moves: 0.875000.
#     Number of archive updates: 35.
#     Fraction of archive updates in accepted moves: 0.200000.
# ------
# TEMPERATURE: 0.254187
#     Number of accepted moves: 171.
#     Fraction of accepted moves: 0.855000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.146199.
# ------
# TEMPERATURE: 0.228768
#     Number of accepted moves: 156.
#     Fraction of accepted moves: 0.780000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.134615.
# ------
# TEMPERATURE: 0.205891
#     Number of accepted moves: 165.
#     Fraction of accepted moves: 0.825000.
#     Number of archive updates: 29.
#     Fraction of archive updates in accepted moves: 0.175758.
# ------
# TEMPERATURE: 0.185302
#     Number of accepted moves: 157.
#     Fraction of accepted moves: 0.785000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.070064.
# ------
# TEMPERATURE: 0.166772
#     Number of accepted moves: 168.
#     Fraction of accepted moves: 0.840000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.065476.
# ------
# TEMPERATURE: 0.150095
#     Number of accepted moves: 158.
#     Fraction of accepted moves: 0.790000.
#     Number of archive updates: 27.
#     Fraction of archive updates in accepted moves: 0.170886.
# ------
# TEMPERATURE: 0.135085
#     Number of accepted moves: 175.
#     Fraction of accepted moves: 0.875000.
#     Number of archive updates: 53.
#     Fraction of archive updates in accepted moves: 0.302857.
# ------
# TEMPERATURE: 0.121577
#     Number of accepted moves: 145.
#     Fraction of accepted moves: 0.725000.
#     Number of archive updates: 26.
#     Fraction of archive updates in accepted moves: 0.179310.
# ------
# TEMPERATURE: 0.109419
#     Number of accepted moves: 160.
#     Fraction of accepted moves: 0.800000.
#     Number of archive updates: 68.
#     Fraction of archive updates in accepted moves: 0.425000.
# ------
# TEMPERATURE: 0.098477
#     Number of accepted moves: 148.
#     Fraction of accepted moves: 0.740000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.020270.
# ------
# TEMPERATURE: 0.088629
#     Number of accepted moves: 141.
#     Fraction of accepted moves: 0.705000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.148936.
# ------
# TEMPERATURE: 0.079766
#     Number of accepted moves: 145.
#     Fraction of accepted moves: 0.725000.
#     Number of archive updates: 42.
#     Fraction of archive updates in accepted moves: 0.289655.
# ------
# TEMPERATURE: 0.071790
#     Number of accepted moves: 138.
#     Fraction of accepted moves: 0.690000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.101449.
# ------
# TEMPERATURE: 0.064611
#     Number of accepted moves: 139.
#     Fraction of accepted moves: 0.695000.
#     Number of archive updates: 38.
#     Fraction of archive updates in accepted moves: 0.273381.
# ------
# TEMPERATURE: 0.058150
#     Number of accepted moves: 136.
#     Fraction of accepted moves: 0.680000.
#     Number of archive updates: 62.
#     Fraction of archive updates in accepted moves: 0.455882.
# ------
# TEMPERATURE: 0.052335
#     Number of accepted moves: 131.
#     Fraction of accepted moves: 0.655000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.160305.
# ------
# TEMPERATURE: 0.047101
#     Number of accepted moves: 147.
#     Fraction of accepted moves: 0.735000.
#     Number of archive updates: 30.
#     Fraction of archive updates in accepted moves: 0.204082.
# ------
# TEMPERATURE: 0.042391
#     Number of accepted moves: 109.
#     Fraction of accepted moves: 0.545000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.055046.
# ------
# TEMPERATURE: 0.038152
#     Number of accepted moves: 119.
#     Fraction of accepted moves: 0.595000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.100840.
# ------
# TEMPERATURE: 0.034337
#     Number of accepted moves: 122.
#     Fraction of accepted moves: 0.610000.
#     Number of archive updates: 28.
#     Fraction of archive updates in accepted moves: 0.229508.
# ------
# TEMPERATURE: 0.030903
#     Number of accepted moves: 106.
#     Fraction of accepted moves: 0.530000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.207547.
# ------
# TEMPERATURE: 0.027813
#     Number of accepted moves: 111.
#     Fraction of accepted moves: 0.555000.
#     Number of archive updates: 31.
#     Fraction of archive updates in accepted moves: 0.279279.
# ------
# TEMPERATURE: 0.025032
#     Number of accepted moves: 117.
#     Fraction of accepted moves: 0.585000.
#     Number of archive updates: 48.
#     Fraction of archive updates in accepted moves: 0.410256.
# ------
# TEMPERATURE: 0.022528
#     Number of accepted moves: 132.
#     Fraction of accepted moves: 0.660000.
#     Number of archive updates: 104.
#     Fraction of archive updates in accepted moves: 0.787879.
# ------
# TEMPERATURE: 0.020276
#     Number of accepted moves: 128.
#     Fraction of accepted moves: 0.640000.
#     Number of archive updates: 53.
#     Fraction of archive updates in accepted moves: 0.414062.
# ------
# TEMPERATURE: 0.018248
#     Number of accepted moves: 71.
#     Fraction of accepted moves: 0.355000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.042254.
# ------
# TEMPERATURE: 0.016423
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.405000.
#     No archive update.
# ------
# TEMPERATURE: 0.014781
#     Number of accepted moves: 79.
#     Fraction of accepted moves: 0.395000.
#     Number of archive updates: 27.
#     Fraction of archive updates in accepted moves: 0.341772.
# ------
# TEMPERATURE: 0.013303
#     Number of accepted moves: 88.
#     Fraction of accepted moves: 0.440000.
#     Number of archive updates: 54.
#     Fraction of archive updates in accepted moves: 0.613636.
# ------
# TEMPERATURE: 0.011973
#     Number of accepted moves: 77.
#     Fraction of accepted moves: 0.385000.
#     Number of archive updates: 26.
#     Fraction of archive updates in accepted moves: 0.337662.
# ------
# TEMPERATURE: 0.010775
#     Number of accepted moves: 100.
#     Fraction of accepted moves: 0.500000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.190000.
# ------
# TEMPERATURE: 0.009698
#     Number of accepted moves: 82.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 37.
#     Fraction of archive updates in accepted moves: 0.451220.
# ------
# TEMPERATURE: 0.008728
#     Number of accepted moves: 88.
#     Fraction of accepted moves: 0.440000.
#     No archive update.
# ------
# TEMPERATURE: 0.007855
#     Number of accepted moves: 102.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.009804.
# ------
# TEMPERATURE: 0.007070
#     Number of accepted moves: 38.
#     Fraction of accepted moves: 0.190000.
#     No archive update.
# ------
# TEMPERATURE: 0.006363
#     Number of accepted moves: 66.
#     Fraction of accepted moves: 0.330000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.015152.
# ------
# TEMPERATURE: 0.005726
#     Number of accepted moves: 61.
#     Fraction of accepted moves: 0.305000.
#     No archive update.
# ------
# TEMPERATURE: 0.005154
#     Number of accepted moves: 99.
#     Fraction of accepted moves: 0.495000.
#     No archive update.
# ------
# TEMPERATURE: 0.004638
#     Number of accepted moves: 14.
#     Fraction of accepted moves: 0.070000.
#     No archive update.
# ------
# TEMPERATURE: 0.004175
#     Number of accepted moves: 30.
#     Fraction of accepted moves: 0.150000.
#     No archive update.
# ------
# TEMPERATURE: 0.003757
#     Insertion in the archive consecutively rejected 1000 times!
#     Stoping at iteration 99...
# ------
#
# --- THE END ---
# CPU times: total: 1.17 s
# Wall time: 1.45 s

# %% [markdown]
# ### Output 3

# %%
print(f"Number of solutions stored in the third archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the third archive: 1000

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.799327920980645, 14.317750851995164]
# Max: [-21.921462945649722, 222.073146680535]
# Avg: [-27.384095030985407, 90.88039783761397]
# Std: [1.1811224288024582, 54.739712801588034]

# %%
opt.plot_front()

# %% [markdown]
# ### Merges the three solution archives and removes the dominated solutions from the resulting archive
#
# Merging archives from different runs provides a simple manner of performing parallel runs.

# %%
# %%time
merged = opt.mergex([archive1, archive2, archive3])
pruned = opt.prune_dominated(xset=merged)
opt.savex(xset=pruned, archive_file="merged_archive.json")
# Out:
# CPU times: total: 922 ms
# Wall time: 1.51 s

# %%
print(f"Number of solutions stored in the merged archive: {opt.sizex(pruned)}")
# Out:
# Number of solutions stored in the merged archive: 2837

# %%
for key, value in opt.get_stats().items():
    print(f"{key}: {value}")
# Out:
# Min: [-28.799327920980645, 14.317750851995164]
# Max: [-21.921462945649722, 222.073146680535]
# Avg: [-27.384095030985407, 90.88039783761397]
# Std: [1.1811224288024582, 54.739712801588034]

# %%
opt.plot_front(pruned)

# %% [markdown]
# ### Decision making
#
# Many solutions (i.e., candidate alloys) still remain in the archive and it is hard to choose one or two out of them.
#
# In order to reduce the solution set to something a human being is able to deal with, first, the *trimx* method is
# used to select only the alloys that present a reasonable (according to the users needs) value of the *X* property.

# %%
trimmed = opt.trimx(xset=pruned, thresholds=[-27.0, None])
print(f"Number of solutions stored in the reduced archive: {opt.sizex(trimmed)}")
# Out:
# Number of solutions stored in the reduced archive: 2263

# %% [markdown]
# The next step is to further reduce the number of solutions. Below, we use the *reducex* method to select 10 alloying candidates with the lowest cost, assuming cost is the most important variable for the user.
#
# As can be seen, **V** alloys with more than 9\% **I** added as an alloying element are the optimized alloys considering the user needs.

# %%
sol1 = opt.reducex(xset=trimmed, index=1, nel=10)
opt.printx(sol1)
# Out:
# 0) Component: [V, I], Concentration: 0.09988059398872183 ===> [-27.028722844349495, 63.37327045195208]
# 1) Component: [V, I], Concentration: 0.09969338681843057 ===> [-27.029785709130955, 63.383476531237164]
# 2) Component: [V, I], Concentration: 0.09967507574016812 ===> [-27.029889669893596, 63.384474806657124]
# 3) Component: [V, I], Concentration: 0.09858762697063181 ===> [-27.03606363746642, 63.443759866855856]
# 4) Component: [V, I], Concentration: 0.09849833994378318 ===> [-27.036570562687977, 63.44862757824602]
# 5) Component: [V, I], Concentration: 0.09783408438244869 ===> [-27.040341859700433, 63.48484117473375]
# 6) Component: [V, I], Concentration: 0.09766853526459743 ===> [-27.04128176134358, 63.493866509712845]
# 7) Component: [V, I], Concentration: 0.09737721137730568 ===> [-27.042935746601284, 63.50974877900152]
# 8) Component: [V, I], Concentration: 0.09672218553820747 ===> [-27.046654642059394, 63.54545919349694]
# 9) Component: [V, I], Concentration: 0.09665871815188756 ===> [-27.04701497681359, 63.548919280927294]

# %% [markdown]
# To reduce the number of candidates even further, we use the *reducex* method again, but now to select 5 alloy candidates with the highest value of the *X* property.

# %%
sol2 = opt.reducex(xset=sol1, index=0, nel=5)
opt.printx(sol2)
# Out:
# 0) Component: [V, I], Concentration: 0.09665871815188756 ===> [-27.04701497681359, 63.548919280927294]
# 1) Component: [V, I], Concentration: 0.09672218553820747 ===> [-27.046654642059394, 63.54545919349694]
# 2) Component: [V, I], Concentration: 0.09737721137730568 ===> [-27.042935746601284, 63.50974877900152]
# 3) Component: [V, I], Concentration: 0.09766853526459743 ===> [-27.04128176134358, 63.493866509712845]
# 4) Component: [V, I], Concentration: 0.09783408438244869 ===> [-27.040341859700433, 63.48484117473375]

# %% [markdown]
# As an alternative to manually reducing the archive in multiple steps, we can use the *bestx* method to select a single candidate alloy by means of the TOPSIS decision-making criterion.

# %%
best_alloy = opt.bestx(xset=trimmed)
opt.printx(best_alloy)
# Out:
# 0) Component: [V, R], Concentration: 0.09997473981079008 ===> [-27.412569755936158, 65.41868547183883]
