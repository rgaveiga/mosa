# %% [markdown]
# ## Binh and Korn function
#
# Problem taken from \[Binh T. and Korn U. (1997) MOBES: A Multiobjective Evolution Strategy for Constrained Optimization Problems. In: Proceedings of the Third International Conference on Genetic Algorithms. Czech Republic. pp. 176–182\], defined as follows:
#
# ---
#
# *Minimize*
#
# $f_1 (x_1,x_2) = 4x_1^2+4x_2^2$
#
# $f_2 (x_1,x_2) = (x_1 - 5)^2+(x_2-5)^2$
#
# *subjected to*
#
# $(x_1 - 5)^2+x_2^2 \le 25$
#
# $(x_1 - 8)^2+(x_2+3)^2 \ge 7.7$
#
# *in the domain*
#
# $0 \le x_1 \le 5$
#
# $0 \le x_2 \le 3$

# %%
import mosa
from math import inf
from numpy.random import seed

# %matplotlib inline

# %%
seed(0)

# %% [markdown]
# ### Translates the Binh and Korn problem into Python code
#
# In the Python function *fobj* below, $f_1$ and $f_2$ are the objective functions to be minimized.
#
# The solution to the problem is given by $X_1$ and $X_2$.
#
# The constraints are defined as $c_1$ and $c_2$. If they are not fulfilled, infinity is assigned to $f_1$ and $f_2$.

# %%
def fobj(X1: float, X2: float) -> tuple:
    f1 = 4.0 * (pow(X1, 2) + pow(X2, 2))
    f2 = pow((X1 - 5), 2) + pow((X2 - 5), 2)

    c1 = pow((X1 - 5), 2) + pow((X2), 2)
    c2 = pow((X1 - 8), 2) + pow((X2 + 3), 2)

    if c1 > 25.0 or c2 < 7.7:
        f1 = inf
        f2 = inf

    return f1, f2

# %% [markdown]
# ### Initialization

# %%
opt = mosa.Anneal()
# Out:
# --------------------------------------------------
#  MULTI-OBJECTIVE SIMULATED ANNEALING (MOSA) 1.0.0
# --------------------------------------------------

# %%
opt.set_population(X1=(0.0, 5.0), X2=(0.0, 3.0))

# %%
opt.archive_size = 10000
opt.maximum_archive_rejections = 1000

# %% [markdown]
# ### Hot run
#
# A first run starting at very high temperature (1000.0) is performed. This initial "hot run" helps the algorithm not to be trapped.

# %%
opt.initial_temperature = 1000.0
opt.number_of_iterations = 100
opt.number_of_temperatures = 100
opt.temperature_decrease_factor = 0.95
opt.verbose = True
opt.adaptative_mc_step = True    # Maximum MC step size is adjusted using Corana's algorithm

# %%
opt.set_opt_param("number_of_elements", X1=1, X2=1)

# %%
# %%time
opt.evolve(fobj)
# Out:
# --- BEGIN: Evolving a solution ---
#
# Trying to load the archive from file archive.json...
# File archive.json not found or invalid! Initializing an empty archive...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     X1:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,5.0)
#         Selection probability: 0.500000
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.5
#     X2:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,3.0)
#         Selection probability: 0.500000
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.3
# ------
# Initializing with a random solution from scratch...
# Done!
# ------
# TEMPERATURE: 1000.000000
#     Number of accepted moves: 99.
#     Fraction of accepted moves: 0.990000.
#     Number of archive updates: 60.
#     Fraction of archive updates in accepted moves: 0.606061.
# ------
# TEMPERATURE: 950.000000
#     Number of accepted moves: 94.
#     Fraction of accepted moves: 0.940000.
#     Number of archive updates: 35.
#     Fraction of archive updates in accepted moves: 0.372340.
# ------
# TEMPERATURE: 902.500000
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 30.
#     Fraction of archive updates in accepted moves: 0.315789.
# ------
# TEMPERATURE: 857.375000
#     Number of accepted moves: 96.
#     Fraction of accepted moves: 0.960000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.197917.
# ------
# TEMPERATURE: 814.506250
#     Number of accepted moves: 92.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 33.
#     Fraction of archive updates in accepted moves: 0.358696.
# ------
# TEMPERATURE: 773.780937
#     Number of accepted moves: 96.
#     Fraction of accepted moves: 0.960000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.218750.
# ------
# TEMPERATURE: 735.091891
#     Number of accepted moves: 94.
#     Fraction of accepted moves: 0.940000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.244681.
# ------
# TEMPERATURE: 698.337296
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.231579.
# ------
# TEMPERATURE: 663.420431
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.231579.
# ------
# TEMPERATURE: 630.249410
#     Number of accepted moves: 90.
#     Fraction of accepted moves: 0.900000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.188889.
# ------
# TEMPERATURE: 598.736939
#     Number of accepted moves: 97.
#     Fraction of accepted moves: 0.970000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.103093.
# ------
# TEMPERATURE: 568.800092
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.189474.
# ------
# TEMPERATURE: 540.360088
#     Number of accepted moves: 92.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.228261.
# ------
# TEMPERATURE: 513.342083
#     Number of accepted moves: 96.
#     Fraction of accepted moves: 0.960000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.208333.
# ------
# TEMPERATURE: 487.674979
#     Number of accepted moves: 92.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.206522.
# ------
# TEMPERATURE: 463.291230
#     Number of accepted moves: 92.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.206522.
# ------
# TEMPERATURE: 440.126669
#     Number of accepted moves: 88.
#     Fraction of accepted moves: 0.880000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.113636.
# ------
# TEMPERATURE: 418.120335
#     Number of accepted moves: 93.
#     Fraction of accepted moves: 0.930000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.161290.
# ------
# TEMPERATURE: 397.214318
#     Number of accepted moves: 89.
#     Fraction of accepted moves: 0.890000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.146067.
# ------
# TEMPERATURE: 377.353603
#     Number of accepted moves: 92.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.108696.
# ------
# TEMPERATURE: 358.485922
#     Number of accepted moves: 94.
#     Fraction of accepted moves: 0.940000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.117021.
# ------
# TEMPERATURE: 340.561626
#     Number of accepted moves: 90.
#     Fraction of accepted moves: 0.900000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.066667.
# ------
# TEMPERATURE: 323.533545
#     Number of accepted moves: 92.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.141304.
# ------
# TEMPERATURE: 307.356868
#     Number of accepted moves: 95.
#     Fraction of accepted moves: 0.950000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.084211.
# ------
# TEMPERATURE: 291.989024
#     Number of accepted moves: 93.
#     Fraction of accepted moves: 0.930000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.161290.
# ------
# TEMPERATURE: 277.389573
#     Number of accepted moves: 90.
#     Fraction of accepted moves: 0.900000.
#     Number of archive updates: 16.
#     Fraction of archive updates in accepted moves: 0.177778.
# ------
# TEMPERATURE: 263.520094
#     Number of accepted moves: 93.
#     Fraction of accepted moves: 0.930000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.096774.
# ------
# TEMPERATURE: 250.344090
#     Number of accepted moves: 94.
#     Fraction of accepted moves: 0.940000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.053191.
# ------
# TEMPERATURE: 237.826885
#     Number of accepted moves: 87.
#     Fraction of accepted moves: 0.870000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.091954.
# ------
# TEMPERATURE: 225.935541
#     Number of accepted moves: 91.
#     Fraction of accepted moves: 0.910000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.164835.
# ------
# TEMPERATURE: 214.638764
#     Number of accepted moves: 89.
#     Fraction of accepted moves: 0.890000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.112360.
# ------
# TEMPERATURE: 203.906826
#     Number of accepted moves: 85.
#     Fraction of accepted moves: 0.850000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.129412.
# ------
# TEMPERATURE: 193.711484
#     Number of accepted moves: 86.
#     Fraction of accepted moves: 0.860000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.139535.
# ------
# TEMPERATURE: 184.025910
#     Number of accepted moves: 90.
#     Fraction of accepted moves: 0.900000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.111111.
# ------
# TEMPERATURE: 174.824615
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.810000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.098765.
# ------
# TEMPERATURE: 166.083384
#     Number of accepted moves: 90.
#     Fraction of accepted moves: 0.900000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.066667.
# ------
# TEMPERATURE: 157.779215
#     Number of accepted moves: 89.
#     Fraction of accepted moves: 0.890000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.146067.
# ------
# TEMPERATURE: 149.890254
#     Number of accepted moves: 92.
#     Fraction of accepted moves: 0.920000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.141304.
# ------
# TEMPERATURE: 142.395741
#     Number of accepted moves: 80.
#     Fraction of accepted moves: 0.800000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.125000.
# ------
# TEMPERATURE: 135.275954
#     Number of accepted moves: 90.
#     Fraction of accepted moves: 0.900000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.066667.
# ------
# TEMPERATURE: 128.512157
#     Number of accepted moves: 73.
#     Fraction of accepted moves: 0.730000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.123288.
# ------
# TEMPERATURE: 122.086549
#     Number of accepted moves: 85.
#     Fraction of accepted moves: 0.850000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.117647.
# ------
# TEMPERATURE: 115.982221
#     Number of accepted moves: 88.
#     Fraction of accepted moves: 0.880000.
#     Number of archive updates: 16.
#     Fraction of archive updates in accepted moves: 0.181818.
# ------
# TEMPERATURE: 110.183110
#     Number of accepted moves: 88.
#     Fraction of accepted moves: 0.880000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.147727.
# ------
# TEMPERATURE: 104.673955
#     Number of accepted moves: 84.
#     Fraction of accepted moves: 0.840000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.083333.
# ------
# TEMPERATURE: 99.440257
#     Number of accepted moves: 86.
#     Fraction of accepted moves: 0.860000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.139535.
# ------
# TEMPERATURE: 94.468244
#     Number of accepted moves: 72.
#     Fraction of accepted moves: 0.720000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.097222.
# ------
# TEMPERATURE: 89.744832
#     Number of accepted moves: 79.
#     Fraction of accepted moves: 0.790000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.177215.
# ------
# TEMPERATURE: 85.257590
#     Number of accepted moves: 67.
#     Fraction of accepted moves: 0.670000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.208955.
# ------
# TEMPERATURE: 80.994711
#     Number of accepted moves: 83.
#     Fraction of accepted moves: 0.830000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.132530.
# ------
# TEMPERATURE: 76.944975
#     Number of accepted moves: 77.
#     Fraction of accepted moves: 0.770000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.038961.
# ------
# TEMPERATURE: 73.097727
#     Number of accepted moves: 78.
#     Fraction of accepted moves: 0.780000.
#     Number of archive updates: 13.
#     Fraction of archive updates in accepted moves: 0.166667.
# ------
# TEMPERATURE: 69.442840
#     Number of accepted moves: 77.
#     Fraction of accepted moves: 0.770000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.038961.
# ------
# TEMPERATURE: 65.970698
#     Number of accepted moves: 78.
#     Fraction of accepted moves: 0.780000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.115385.
# ------
# TEMPERATURE: 62.672163
#     Number of accepted moves: 72.
#     Fraction of accepted moves: 0.720000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.125000.
# ------
# TEMPERATURE: 59.538555
#     Number of accepted moves: 74.
#     Fraction of accepted moves: 0.740000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.067568.
# ------
# TEMPERATURE: 56.561627
#     Number of accepted moves: 67.
#     Fraction of accepted moves: 0.670000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.059701.
# ------
# TEMPERATURE: 53.733546
#     Number of accepted moves: 81.
#     Fraction of accepted moves: 0.810000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.061728.
# ------
# TEMPERATURE: 51.046869
#     Number of accepted moves: 77.
#     Fraction of accepted moves: 0.770000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.038961.
# ------
# TEMPERATURE: 48.494525
#     Number of accepted moves: 61.
#     Fraction of accepted moves: 0.610000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.114754.
# ------
# TEMPERATURE: 46.069799
#     Number of accepted moves: 70.
#     Fraction of accepted moves: 0.700000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.100000.
# ------
# TEMPERATURE: 43.766309
#     Number of accepted moves: 63.
#     Fraction of accepted moves: 0.630000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.142857.
# ------
# TEMPERATURE: 41.577994
#     Number of accepted moves: 69.
#     Fraction of accepted moves: 0.690000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.086957.
# ------
# TEMPERATURE: 39.499094
#     Number of accepted moves: 65.
#     Fraction of accepted moves: 0.650000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.123077.
# ------
# TEMPERATURE: 37.524139
#     Number of accepted moves: 72.
#     Fraction of accepted moves: 0.720000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.097222.
# ------
# TEMPERATURE: 35.647932
#     Number of accepted moves: 67.
#     Fraction of accepted moves: 0.670000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.208955.
# ------
# TEMPERATURE: 33.865536
#     Number of accepted moves: 61.
#     Fraction of accepted moves: 0.610000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.163934.
# ------
# TEMPERATURE: 32.172259
#     Number of accepted moves: 63.
#     Fraction of accepted moves: 0.630000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.158730.
# ------
# TEMPERATURE: 30.563646
#     Number of accepted moves: 70.
#     Fraction of accepted moves: 0.700000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.114286.
# ------
# TEMPERATURE: 29.035464
#     Number of accepted moves: 56.
#     Fraction of accepted moves: 0.560000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.071429.
# ------
# TEMPERATURE: 27.583690
#     Number of accepted moves: 60.
#     Fraction of accepted moves: 0.600000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.100000.
# ------
# TEMPERATURE: 26.204506
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.590000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.067797.
# ------
# TEMPERATURE: 24.894281
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.590000.
#     No archive update.
# ------
# TEMPERATURE: 23.649567
#     Number of accepted moves: 56.
#     Fraction of accepted moves: 0.560000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.089286.
# ------
# TEMPERATURE: 22.467088
#     Number of accepted moves: 64.
#     Fraction of accepted moves: 0.640000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.187500.
# ------
# TEMPERATURE: 21.343734
#     Number of accepted moves: 65.
#     Fraction of accepted moves: 0.650000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.184615.
# ------
# TEMPERATURE: 20.276547
#     Number of accepted moves: 49.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.163265.
# ------
# TEMPERATURE: 19.262720
#     Number of accepted moves: 50.
#     Fraction of accepted moves: 0.500000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.180000.
# ------
# TEMPERATURE: 18.299584
#     Number of accepted moves: 51.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.176471.
# ------
# TEMPERATURE: 17.384605
#     Number of accepted moves: 55.
#     Fraction of accepted moves: 0.550000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.127273.
# ------
# TEMPERATURE: 16.515374
#     Number of accepted moves: 56.
#     Fraction of accepted moves: 0.560000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.142857.
# ------
# TEMPERATURE: 15.689606
#     Number of accepted moves: 56.
#     Fraction of accepted moves: 0.560000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.089286.
# ------
# TEMPERATURE: 14.905125
#     Number of accepted moves: 58.
#     Fraction of accepted moves: 0.580000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.137931.
# ------
# TEMPERATURE: 14.159869
#     Number of accepted moves: 57.
#     Fraction of accepted moves: 0.570000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.087719.
# ------
# TEMPERATURE: 13.451876
#     Number of accepted moves: 49.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.142857.
# ------
# TEMPERATURE: 12.779282
#     Number of accepted moves: 52.
#     Fraction of accepted moves: 0.520000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.173077.
# ------
# TEMPERATURE: 12.140318
#     Number of accepted moves: 49.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.102041.
# ------
# TEMPERATURE: 11.533302
#     Number of accepted moves: 45.
#     Fraction of accepted moves: 0.450000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.111111.
# ------
# TEMPERATURE: 10.956637
#     Number of accepted moves: 48.
#     Fraction of accepted moves: 0.480000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.187500.
# ------
# TEMPERATURE: 10.408805
#     Number of accepted moves: 44.
#     Fraction of accepted moves: 0.440000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.204545.
# ------
# TEMPERATURE: 9.888365
#     Number of accepted moves: 51.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.078431.
# ------
# TEMPERATURE: 9.393946
#     Number of accepted moves: 40.
#     Fraction of accepted moves: 0.400000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.100000.
# ------
# TEMPERATURE: 8.924249
#     Number of accepted moves: 42.
#     Fraction of accepted moves: 0.420000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.095238.
# ------
# TEMPERATURE: 8.478037
#     Number of accepted moves: 46.
#     Fraction of accepted moves: 0.460000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.195652.
# ------
# TEMPERATURE: 8.054135
#     Number of accepted moves: 38.
#     Fraction of accepted moves: 0.380000.
#     Number of archive updates: 6.
#     Fraction of archive updates in accepted moves: 0.157895.
# ------
# TEMPERATURE: 7.651428
#     Number of accepted moves: 51.
#     Fraction of accepted moves: 0.510000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.156863.
# ------
# TEMPERATURE: 7.268857
#     Number of accepted moves: 42.
#     Fraction of accepted moves: 0.420000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.047619.
# ------
# TEMPERATURE: 6.905414
#     Number of accepted moves: 58.
#     Fraction of accepted moves: 0.580000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.206897.
# ------
# TEMPERATURE: 6.560143
#     Number of accepted moves: 43.
#     Fraction of accepted moves: 0.430000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.232558.
# ------
# TEMPERATURE: 6.232136
#     Number of accepted moves: 52.
#     Fraction of accepted moves: 0.520000.
#     Number of archive updates: 14.
#     Fraction of archive updates in accepted moves: 0.269231.
# ------
#
# --- THE END ---
# CPU times: total: 688 ms
# Wall time: 1.31 s

# %%
print(f"Number of solutions stored in the archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the archive: 736

# %% [markdown]
# ### Cold run
#
# After the "hot run", a "cold run" starting at a much lower temperature (1.0) is performed to allow the solutions to relax to the vicinity of the Pareto front.

# %%
opt.initial_temperature = 1.0

# %%
opt.set_opt_param("mc_step_size", X1=0.05, X2=0.03)

# %%
# %%time
opt.evolve(fobj)
# Out:
# --- BEGIN: Evolving a solution ---
#
# Restarting from a previous run...
# Done!
# ------
#
# Groups in the solution:
# ======================
#
#     X1:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,5.0)
#         Selection probability: 0.500000
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.05
#     X2:
#         Number of elements: 1
#         Sample space: continuous
#         Boundaries: (0.0,3.0)
#         Selection probability: 0.500000
#         Weight of 'change value' trial move: 1.0
#         Sort values: False
#         Maximum step size: 0.03
# ------
# Initial solution loaded from the archive...
# Done!
# ------
# TEMPERATURE: 1.000000
#     Number of accepted moves: 87.
#     Fraction of accepted moves: 0.870000.
#     Number of archive updates: 52.
#     Fraction of archive updates in accepted moves: 0.597701.
# ------
# TEMPERATURE: 0.950000
#     Number of accepted moves: 72.
#     Fraction of accepted moves: 0.720000.
#     Number of archive updates: 30.
#     Fraction of archive updates in accepted moves: 0.416667.
# ------
# TEMPERATURE: 0.902500
#     Number of accepted moves: 52.
#     Fraction of accepted moves: 0.520000.
#     Number of archive updates: 17.
#     Fraction of archive updates in accepted moves: 0.326923.
# ------
# TEMPERATURE: 0.857375
#     Number of accepted moves: 47.
#     Fraction of accepted moves: 0.470000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.531915.
# ------
# TEMPERATURE: 0.814506
#     Number of accepted moves: 45.
#     Fraction of accepted moves: 0.450000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.466667.
# ------
# TEMPERATURE: 0.773781
#     Number of accepted moves: 53.
#     Fraction of accepted moves: 0.530000.
#     Number of archive updates: 24.
#     Fraction of archive updates in accepted moves: 0.452830.
# ------
# TEMPERATURE: 0.735092
#     Number of accepted moves: 56.
#     Fraction of accepted moves: 0.560000.
#     Number of archive updates: 20.
#     Fraction of archive updates in accepted moves: 0.357143.
# ------
# TEMPERATURE: 0.698337
#     Number of accepted moves: 42.
#     Fraction of accepted moves: 0.420000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.023810.
# ------
# TEMPERATURE: 0.663420
#     Number of accepted moves: 44.
#     Fraction of accepted moves: 0.440000.
#     No archive update.
# ------
# TEMPERATURE: 0.630249
#     Number of accepted moves: 49.
#     Fraction of accepted moves: 0.490000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.204082.
# ------
# TEMPERATURE: 0.598737
#     Number of accepted moves: 44.
#     Fraction of accepted moves: 0.440000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.340909.
# ------
# TEMPERATURE: 0.568800
#     Number of accepted moves: 43.
#     Fraction of accepted moves: 0.430000.
#     No archive update.
# ------
# TEMPERATURE: 0.540360
#     Number of accepted moves: 53.
#     Fraction of accepted moves: 0.530000.
#     Number of archive updates: 4.
#     Fraction of archive updates in accepted moves: 0.075472.
# ------
# TEMPERATURE: 0.513342
#     Number of accepted moves: 46.
#     Fraction of accepted moves: 0.460000.
#     Number of archive updates: 23.
#     Fraction of archive updates in accepted moves: 0.500000.
# ------
# TEMPERATURE: 0.487675
#     Number of accepted moves: 41.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.292683.
# ------
# TEMPERATURE: 0.463291
#     Number of accepted moves: 50.
#     Fraction of accepted moves: 0.500000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.220000.
# ------
# TEMPERATURE: 0.440127
#     Number of accepted moves: 52.
#     Fraction of accepted moves: 0.520000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.480769.
# ------
# TEMPERATURE: 0.418120
#     Number of accepted moves: 41.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.268293.
# ------
# TEMPERATURE: 0.397214
#     Number of accepted moves: 39.
#     Fraction of accepted moves: 0.390000.
#     Number of archive updates: 11.
#     Fraction of archive updates in accepted moves: 0.282051.
# ------
# TEMPERATURE: 0.377354
#     Number of accepted moves: 41.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 0.512195.
# ------
# TEMPERATURE: 0.358486
#     Number of accepted moves: 34.
#     Fraction of accepted moves: 0.340000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.647059.
# ------
# TEMPERATURE: 0.340562
#     Number of accepted moves: 41.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 28.
#     Fraction of archive updates in accepted moves: 0.682927.
# ------
# TEMPERATURE: 0.323534
#     Number of accepted moves: 38.
#     Fraction of accepted moves: 0.380000.
#     Number of archive updates: 28.
#     Fraction of archive updates in accepted moves: 0.736842.
# ------
# TEMPERATURE: 0.307357
#     Number of accepted moves: 59.
#     Fraction of accepted moves: 0.590000.
#     Number of archive updates: 2.
#     Fraction of archive updates in accepted moves: 0.033898.
# ------
# TEMPERATURE: 0.291989
#     Number of accepted moves: 46.
#     Fraction of accepted moves: 0.460000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.543478.
# ------
# TEMPERATURE: 0.277390
#     Number of accepted moves: 48.
#     Fraction of accepted moves: 0.480000.
#     Number of archive updates: 41.
#     Fraction of archive updates in accepted moves: 0.854167.
# ------
# TEMPERATURE: 0.263520
#     Number of accepted moves: 38.
#     Fraction of accepted moves: 0.380000.
#     Number of archive updates: 10.
#     Fraction of archive updates in accepted moves: 0.263158.
# ------
# TEMPERATURE: 0.250344
#     Number of accepted moves: 43.
#     Fraction of accepted moves: 0.430000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.418605.
# ------
# TEMPERATURE: 0.237827
#     Number of accepted moves: 38.
#     Fraction of accepted moves: 0.380000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.236842.
# ------
# TEMPERATURE: 0.225936
#     Number of accepted moves: 40.
#     Fraction of accepted moves: 0.400000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.125000.
# ------
# TEMPERATURE: 0.214639
#     Number of accepted moves: 48.
#     Fraction of accepted moves: 0.480000.
#     Number of archive updates: 12.
#     Fraction of archive updates in accepted moves: 0.250000.
# ------
# TEMPERATURE: 0.203907
#     Number of accepted moves: 47.
#     Fraction of accepted moves: 0.470000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.531915.
# ------
# TEMPERATURE: 0.193711
#     Number of accepted moves: 40.
#     Fraction of accepted moves: 0.400000.
#     Number of archive updates: 33.
#     Fraction of archive updates in accepted moves: 0.825000.
# ------
# TEMPERATURE: 0.184026
#     Number of accepted moves: 37.
#     Fraction of accepted moves: 0.370000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.486486.
# ------
# TEMPERATURE: 0.174825
#     Number of accepted moves: 41.
#     Fraction of accepted moves: 0.410000.
#     Number of archive updates: 37.
#     Fraction of archive updates in accepted moves: 0.902439.
# ------
# TEMPERATURE: 0.166083
#     Number of accepted moves: 32.
#     Fraction of accepted moves: 0.320000.
#     Number of archive updates: 8.
#     Fraction of archive updates in accepted moves: 0.250000.
# ------
# TEMPERATURE: 0.157779
#     Number of accepted moves: 44.
#     Fraction of accepted moves: 0.440000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.068182.
# ------
# TEMPERATURE: 0.149890
#     Number of accepted moves: 35.
#     Fraction of accepted moves: 0.350000.
#     Number of archive updates: 30.
#     Fraction of archive updates in accepted moves: 0.857143.
# ------
# TEMPERATURE: 0.142396
#     Number of accepted moves: 42.
#     Fraction of accepted moves: 0.420000.
#     Number of archive updates: 34.
#     Fraction of archive updates in accepted moves: 0.809524.
# ------
# TEMPERATURE: 0.135276
#     Number of accepted moves: 40.
#     Fraction of accepted moves: 0.400000.
#     Number of archive updates: 35.
#     Fraction of archive updates in accepted moves: 0.875000.
# ------
# TEMPERATURE: 0.128512
#     Number of accepted moves: 39.
#     Fraction of accepted moves: 0.390000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.641026.
# ------
# TEMPERATURE: 0.122087
#     Number of accepted moves: 32.
#     Fraction of accepted moves: 0.320000.
#     No archive update.
# ------
# TEMPERATURE: 0.115982
#     Number of accepted moves: 31.
#     Fraction of accepted moves: 0.310000.
#     Number of archive updates: 25.
#     Fraction of archive updates in accepted moves: 0.806452.
# ------
# TEMPERATURE: 0.110183
#     Number of accepted moves: 37.
#     Fraction of accepted moves: 0.370000.
#     Number of archive updates: 34.
#     Fraction of archive updates in accepted moves: 0.918919.
# ------
# TEMPERATURE: 0.104674
#     Number of accepted moves: 39.
#     Fraction of accepted moves: 0.390000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.025641.
# ------
# TEMPERATURE: 0.099440
#     Number of accepted moves: 29.
#     Fraction of accepted moves: 0.290000.
#     No archive update.
# ------
# TEMPERATURE: 0.094468
#     Number of accepted moves: 31.
#     Fraction of accepted moves: 0.310000.
#     No archive update.
# ------
# TEMPERATURE: 0.089745
#     Number of accepted moves: 28.
#     Fraction of accepted moves: 0.280000.
#     No archive update.
# ------
# TEMPERATURE: 0.085258
#     Number of accepted moves: 31.
#     Fraction of accepted moves: 0.310000.
#     Number of archive updates: 5.
#     Fraction of archive updates in accepted moves: 0.161290.
# ------
# TEMPERATURE: 0.080995
#     Number of accepted moves: 23.
#     Fraction of accepted moves: 0.230000.
#     Number of archive updates: 7.
#     Fraction of archive updates in accepted moves: 0.304348.
# ------
# TEMPERATURE: 0.076945
#     Number of accepted moves: 25.
#     Fraction of accepted moves: 0.250000.
#     Number of archive updates: 3.
#     Fraction of archive updates in accepted moves: 0.120000.
# ------
# TEMPERATURE: 0.073098
#     Number of accepted moves: 23.
#     Fraction of accepted moves: 0.230000.
#     Number of archive updates: 9.
#     Fraction of archive updates in accepted moves: 0.391304.
# ------
# TEMPERATURE: 0.069443
#     Number of accepted moves: 28.
#     Fraction of accepted moves: 0.280000.
#     Number of archive updates: 22.
#     Fraction of archive updates in accepted moves: 0.785714.
# ------
# TEMPERATURE: 0.065971
#     Number of accepted moves: 21.
#     Fraction of accepted moves: 0.210000.
#     Number of archive updates: 21.
#     Fraction of archive updates in accepted moves: 1.000000.
# ------
# TEMPERATURE: 0.062672
#     Number of accepted moves: 16.
#     Fraction of accepted moves: 0.160000.
#     Number of archive updates: 15.
#     Fraction of archive updates in accepted moves: 0.937500.
# ------
# TEMPERATURE: 0.059539
#     Number of accepted moves: 20.
#     Fraction of accepted moves: 0.200000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.900000.
# ------
# TEMPERATURE: 0.056562
#     Number of accepted moves: 24.
#     Fraction of accepted moves: 0.240000.
#     Number of archive updates: 19.
#     Fraction of archive updates in accepted moves: 0.791667.
# ------
# TEMPERATURE: 0.053734
#     Number of accepted moves: 20.
#     Fraction of accepted moves: 0.200000.
#     Number of archive updates: 18.
#     Fraction of archive updates in accepted moves: 0.900000.
# ------
# TEMPERATURE: 0.051047
#     Number of accepted moves: 17.
#     Fraction of accepted moves: 0.170000.
#     Number of archive updates: 16.
#     Fraction of archive updates in accepted moves: 0.941176.
# ------
# TEMPERATURE: 0.048495
#     Number of accepted moves: 19.
#     Fraction of accepted moves: 0.190000.
#     Number of archive updates: 16.
#     Fraction of archive updates in accepted moves: 0.842105.
# ------
# TEMPERATURE: 0.046070
#     Number of accepted moves: 10.
#     Fraction of accepted moves: 0.100000.
#     Number of archive updates: 1.
#     Fraction of archive updates in accepted moves: 0.100000.
# ------
# TEMPERATURE: 0.043766
#     Number of accepted moves: 17.
#     Fraction of accepted moves: 0.170000.
#     No archive update.
# ------
# TEMPERATURE: 0.041578
#     Number of accepted moves: 12.
#     Fraction of accepted moves: 0.120000.
#     No archive update.
# ------
# TEMPERATURE: 0.039499
#     Number of accepted moves: 12.
#     Fraction of accepted moves: 0.120000.
#     No archive update.
# ------
# TEMPERATURE: 0.037524
#     Number of accepted moves: 13.
#     Fraction of accepted moves: 0.130000.
#     No archive update.
# ------
# TEMPERATURE: 0.035648
#     Number of accepted moves: 18.
#     Fraction of accepted moves: 0.180000.
#     No archive update.
# ------
# TEMPERATURE: 0.033866
#     Number of accepted moves: 12.
#     Fraction of accepted moves: 0.120000.
#     No archive update.
# ------
# TEMPERATURE: 0.032172
#     Number of accepted moves: 12.
#     Fraction of accepted moves: 0.120000.
#     No archive update.
# ------
# TEMPERATURE: 0.030564
#     Number of accepted moves: 6.
#     Fraction of accepted moves: 0.060000.
#     No archive update.
# ------
# TEMPERATURE: 0.029035
#     Number of accepted moves: 10.
#     Fraction of accepted moves: 0.100000.
#     No archive update.
# ------
# TEMPERATURE: 0.027584
#     Insertion in the archive consecutively rejected 1000 times!
#     Stoping at iteration 37...
# ------
#
# --- THE END ---
# CPU times: total: 578 ms
# Wall time: 961 ms

# %%
print(f"Number of solutions stored in the archive: {opt.sizex()}")
# Out:
# Number of solutions stored in the archive: 1398

# %% [markdown]
# ### Output

# %%
# %%time
pruned = opt.prune_dominated()
print(f"Number of solutions stored in the pruned archive: {opt.sizex(pruned)}")
# Out:
# Number of solutions stored in the pruned archive: 1398
# CPU times: total: 1.02 s
# Wall time: 1.12 s

# %%
opt.plot_front(pruned)
